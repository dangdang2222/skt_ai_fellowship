# %% [markdown]
# <a href="https://colab.research.google.com/github/dangdang2222/skt_ai_fellowship/blob/main/rve_renew_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, LSTM, Bidirectional, Masking

# keeping the random seed constant from one experiment to the next makes it 
# easier to interpret the effects of hyper-parameters values 
seed = 99
random.seed(seed)
tf.random.set_seed(seed)

def create_model(timesteps, input_dim, intermediate_dim, batch_size, latent_dim, epochs, optimizer):
	# Setup the network parameters:
	timesteps = timesteps
	input_dim = input_dim
	intermediate_dim = intermediate_dim
	batch_size = batch_size
	latent_dim = latent_dim
	epochs = epochs
	if optimizer == 'adam':
		optimizer = keras.optimizers.Adam(learning_rate=0.0001)
	else:
		print("unimplemented optimizer")
		exit(-1)
	masking_value = -99.

	class Sampling(keras.layers.Layer):
		"""Uses (z_mean, sigma) to sample z, the vector encoding an engine trajetory."""
		def call(self, inputs):
			mu, sigma = inputs
			batch = tf.shape(mu)[0]
			dim = tf.shape(mu)[1]
			epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
			return mu + tf.exp(0.5 * sigma) * epsilon
	
	# ----------------------- Encoder -----------------------
	inputs = Input(shape=(timesteps, input_dim,), name='encoder_input')

	mask = Masking(mask_value=masking_value)(inputs)
	
	# LSTM encoding
	h = Bidirectional(LSTM(intermediate_dim))(mask) 

	# VAE Z layer
	mu = Dense(latent_dim)(h)
	sigma = Dense(latent_dim)(h)

	z = Sampling()([mu, sigma])

	# Instantiate the encoder model:
	encoder = keras.Model(inputs, [z, mu, sigma], name='encoder')
	print(encoder.summary())
	# -------------------------------------------------------
	
	# ----------------------- Regressor --------------------
	reg_latent_inputs = Input(shape=(latent_dim,), name='z_sampling_reg')
	reg_intermediate = Dense(200, activation='tanh')(reg_latent_inputs)
	reg_outputs = Dense(1, name='reg_output')(reg_intermediate)
	# Instantiate the classifier model:
	regressor = keras.Model(reg_latent_inputs, reg_outputs, name='regressor')
	print(regressor.summary())
	# -------------------------------------------------------

	''' uncomment if needed
	# ----------------------- Decoder --------------------
	latent_inputs = Input(shape=(latent_dim,), name='z_sampling')
	h_decoded = RepeatVector(timesteps)(latent_inputs)
	h_decoded = Bidirectional(LSTM(intermediate_dim, return_sequences=True))(h_decoded) 
	# decoded layer
	outputs = LSTM(input_dim, return_sequences=True)(h_decoded) 
	# Instantiate the decoder model:
	decoder = keras.Model(latent_inputs, outputs, name='decoder')
	print(decoder.summary())
	# -------------------------------------------------------
	'''
	
	# -------------------- Wrapper model --------------------
	class RVE(keras.Model):
		def __init__(self, encoder, regressor, decoder=None, **kwargs):
			super(RVE, self).__init__(**kwargs)
			self.encoder = encoder
			self.regressor = regressor
			self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
			self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
			self.reg_loss_tracker = keras.metrics.Mean(name="reg_loss")
			self.decoder = decoder
			if self.decoder!=None:
				self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
			

		@property
		def metrics(self):
			if self.decoder!=None:
				return [
					self.total_loss_tracker,
					self.kl_loss_tracker,
					self.reg_loss_tracker,
					self.reconstruction_loss_tracker
				]
			else:
				return [
					self.total_loss_tracker,
					self.kl_loss_tracker,
					self.reg_loss_tracker,
				]

		def train_step(self, data):
			x, target_x = data
			with tf.GradientTape() as tape:
				# kl loss
				z, mu, sigma = self.encoder(x)
				kl_loss = -0.5 * (1 + sigma - tf.square(mu) - tf.exp(sigma))
				kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
				# Regressor
				reg_prediction = self.regressor(z)
				reg_loss = tf.reduce_mean(
					keras.losses.mse(target_x, reg_prediction)
				)
				# Reconstruction
				if self.decoder!=None:
					reconstruction = self.decoder(z)
					reconstruction_loss = tf.reduce_mean(
						keras.losses.mse(x, reconstruction)
					)
					total_loss = kl_loss + reg_loss + reconstruction_loss
					self.reconstruction_loss_tracker.update_state(reconstruction_loss)
				else:
					total_loss = kl_loss + reg_loss
			grads = tape.gradient(total_loss, self.trainable_weights)
			self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
			self.total_loss_tracker.update_state(total_loss)
			self.kl_loss_tracker.update_state(kl_loss)
			self.reg_loss_tracker.update_state(reg_loss)
			return {
				"loss": self.total_loss_tracker.result(),
				"kl_loss": self.kl_loss_tracker.result(),
				"reg_loss": self.reg_loss_tracker.result(),
			}


		def test_step(self, data):
			x, target_x = data

			# kl loss
			z, mu, sigma = self.encoder(x)
			kl_loss = -0.5 * (1 + sigma - tf.square(mu) - tf.exp(sigma))
			kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
			# Regressor
			reg_prediction = self.regressor(z)
			reg_loss = tf.reduce_mean(
				keras.losses.mse(target_x, reg_prediction)
			)
			# Reconstruction
			if self.decoder!=None:
				reconstruction = self.decoder(z)
				reconstruction_loss = tf.reduce_mean(
					keras.losses.mse(x, reconstruction)
				)
				total_loss = kl_loss + reg_loss + reconstruction_loss
			else:
				total_loss = kl_loss + reg_loss

			return {
				"loss": total_loss,
				"kl_loss": kl_loss,
				"reg_loss": reg_loss,
			}
	# -------------------------------------------------------

	rve = RVE(encoder, regressor)
	rve.compile(optimizer=optimizer)

	return rve

# %%
import math
import numpy as np
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint, TensorBoard, LambdaCallback


# --------------------------------------- DATA PRE-PROCESSING ---------------------------------------
def add_remaining_useful_life(df):
    # Get the total number of cycles for each unit
    grouped_by_unit = df.groupby(by="unit_nr")
    max_cycle = grouped_by_unit["time_cycles"].max()
    
    # Merge the max cycle back into the original frame
    result_frame = df.merge(max_cycle.to_frame(name='max_cycle'), left_on='unit_nr', right_index=True)
    
    # Calculate remaining useful life for each row
    remaining_useful_life = result_frame["max_cycle"] - result_frame["time_cycles"]
    result_frame["RUL"] = remaining_useful_life
    
    # drop max_cycle as it's no longer needed
    result_frame = result_frame.drop("max_cycle", axis=1)
    return result_frame

def add_operating_condition(df):
    df_op_cond = df.copy()
    
    df_op_cond['setting_1'] = abs(df_op_cond['setting_1'].round())
    df_op_cond['setting_2'] = abs(df_op_cond['setting_2'].round(decimals=2))
    
    # converting settings to string and concatanating makes the operating condition into a categorical variable
    df_op_cond['op_cond'] = df_op_cond['setting_1'].astype(str) + '_' + \
                        df_op_cond['setting_2'].astype(str) + '_' + \
                        df_op_cond['setting_3'].astype(str)
    
    return df_op_cond

def condition_scaler(df_train, df_test, sensor_names):
    # apply operating condition specific scaling
    scaler = StandardScaler()
    for condition in df_train['op_cond'].unique():
        scaler.fit(df_train.loc[df_train['op_cond']==condition, sensor_names])
        df_train.loc[df_train['op_cond']==condition, sensor_names] = scaler.transform(df_train.loc[df_train['op_cond']==condition, sensor_names])
        df_test.loc[df_test['op_cond']==condition, sensor_names] = scaler.transform(df_test.loc[df_test['op_cond']==condition, sensor_names])
    return df_train, df_test

def exponential_smoothing(df, sensors, n_samples, alpha=0.4):
    df = df.copy()
    # first, take the exponential weighted mean
    k = df.groupby('unit_nr')[sensors].apply(lambda x: x.ewm(alpha=0.1).mean())
    df[sensors] = k
    
    # second, drop first n_samples of each unit_nr to reduce filter delay
    def create_mask(data, samples):
        result = np.ones_like(data)
        result[0:samples] = 0
        return result
    
    mask = df.groupby('unit_nr')['unit_nr'].transform(create_mask, samples=n_samples).astype(bool)
    df = df[mask]
    
    return df

def gen_train_data(df, sequence_length, columns):
    data = df[columns].values
    num_elements = data.shape[0]

    # -1 and +1 because of Python indexing
    for start, stop in zip(range(0, num_elements-(sequence_length-1)), range(sequence_length, num_elements+1)):
        yield data[start:stop, :]
        
def gen_data_wrapper(df, sequence_length, columns, unit_nrs=np.array([])):
    if unit_nrs.size <= 0:
        unit_nrs = df['unit_nr'].unique()
        
    data_gen = (list(gen_train_data(df[df['unit_nr']==unit_nr], sequence_length, columns))
               for unit_nr in unit_nrs)
    data_array = np.concatenate(list(data_gen)).astype(np.float32)
    return data_array

def gen_labels(df, sequence_length, label):
    data_matrix = df[label].values
    num_elements = data_matrix.shape[0]

    # -1 because I want to predict the rul of that last row in the sequence, not the next row
    return data_matrix[sequence_length-1:num_elements, :]  

def gen_label_wrapper(df, sequence_length, label, unit_nrs=np.array([])):
    if unit_nrs.size <= 0:
        unit_nrs = df['unit_nr'].unique()
        
    label_gen = [gen_labels(df[df['unit_nr']==unit_nr], sequence_length, label) 
                for unit_nr in unit_nrs]
    label_array = np.concatenate(label_gen).astype(np.float32)
    return label_array

def gen_test_data(df, sequence_length, columns, mask_value):
    if df.shape[0] < sequence_length:
        data_matrix = np.full(shape=(sequence_length, len(columns)), fill_value=mask_value) # pad
        idx = data_matrix.shape[0] - df.shape[0]
        data_matrix[idx:,:] = df[columns].values  # fill with available data
    else:
        data_matrix = df[columns].values
        
    # specifically yield the last possible sequence
    stop = data_matrix.shape[0]
    start = stop - sequence_length
    for i in list(range(1)):
        yield data_matrix[start:stop, :]  
        
	
def get_data(dataset, sensors, sequence_length, alpha, threshold):
	# files
	dir_path = './drive/MyDrive/CMaps/'
	train_file = 'train_'+dataset+'.txt'
	test_file = 'test_'+dataset+'.txt'
    # columns
	index_names = ['unit_nr', 'time_cycles']
	setting_names = ['setting_1', 'setting_2', 'setting_3']
	sensor_names = ['s_{}'.format(i+1) for i in range(0,21)]
	col_names = index_names + setting_names + sensor_names
    # data readout
	train = pd.read_csv((dir_path+train_file), sep=r'\s+', header=None, 
					 names=col_names)
	test = pd.read_csv((dir_path+test_file), sep=r'\s+', header=None, 
					 names=col_names)
	y_test = pd.read_csv((dir_path+'RUL_'+dataset+'.txt'), sep=r'\s+', header=None, 
					 names=['RemainingUsefulLife'])

    # create RUL values according to the piece-wise target function
	train = add_remaining_useful_life(train)
	train['RUL'].clip(upper=threshold, inplace=True)

    # remove unused sensors
	drop_sensors = [element for element in sensor_names if element not in sensors]

    # scale with respect to the operating condition
	X_train_pre = add_operating_condition(train.drop(drop_sensors, axis=1))
	X_test_pre = add_operating_condition(test.drop(drop_sensors, axis=1))
	X_train_pre, X_test_pre = condition_scaler(X_train_pre, X_test_pre, sensors)

    # exponential smoothing
	X_train_pre= exponential_smoothing(X_train_pre, sensors, 0, alpha)
	X_test_pre = exponential_smoothing(X_test_pre, sensors, 0, alpha)

	# train-val split
	gss = GroupShuffleSplit(n_splits=1, train_size=0.80, random_state=42)
	# generate the train/val for *each* sample -> for that we iterate over the train and val units we want
	# this is a for that iterates only once and in that iterations at the same time iterates over all the values we want,
	# i.e. train_unit and val_unit are not a single value but a set of training/vali units
	for train_unit, val_unit in gss.split(X_train_pre['unit_nr'].unique(), groups=X_train_pre['unit_nr'].unique()): 
		train_unit = X_train_pre['unit_nr'].unique()[train_unit]  # gss returns indexes and index starts at 1
		val_unit = X_train_pre['unit_nr'].unique()[val_unit]

		x_train = gen_data_wrapper(X_train_pre, sequence_length, sensors, train_unit)
		y_train = gen_label_wrapper(X_train_pre, sequence_length, ['RUL'], train_unit)
		
		x_val = gen_data_wrapper(X_train_pre, sequence_length, sensors, val_unit)
		y_val = gen_label_wrapper(X_train_pre, sequence_length, ['RUL'], val_unit)

	# create sequences for test 
	test_gen = (list(gen_test_data(X_test_pre[X_test_pre['unit_nr']==unit_nr], sequence_length, sensors, -99.))
			   for unit_nr in X_test_pre['unit_nr'].unique())
	x_test = np.concatenate(list(test_gen)).astype(np.float32)
	
	return x_train, y_train, x_val, y_val, x_test, y_test['RemainingUsefulLife']
# ---------------------------------------------------------------------------------------------------


# --------------------------------------- TRAINING CALLBACKS  ---------------------------------------
class save_latent_space_viz(Callback):
	def __init__(self, model, data, target):
		self.model = model
		self.data = data
		self.target = target
	
	def on_train_begin(self, logs={}):
		self.best_val_loss = 100000
		
	def on_epoch_end(self, epoch, logs=None):
		encoder = self.model.layers[0]
		if logs.get('val_loss') < self.best_val_loss:
			self.best_val_loss = logs.get('val_loss')
			viz_latent_space(encoder, self.data, self.target, epoch, True, False)
	
def get_callbacks(model, data, target):
	model_callbacks = [
		EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30),
        ModelCheckpoint(filepath='./checkpoints/checkpoint',monitor='val_loss', mode='min', verbose=1, save_best_only=True, save_weights_only=True),
		TensorBoard(log_dir='./logs'),
        save_latent_space_viz(model, data, target)
	]
	return model_callbacks

def viz_latent_space(encoder, data, targets=[], epoch='Final', save=False, show=True):
    z, _, _  = encoder.predict(data)
    # plt.figure(figsize=(8, 10))
    # if len(targets)>0:
    #     plt.scatter(z[:, 0], z[:, 1], c=targets)
    # else:
    #     plt.scatter(z[:, 0], z[:, 1])
    # plt.xlabel('z - dim 1')
    # plt.ylabel('z - dim 2')
    # plt.colorbar()
    # if show:
    #     plt.show()
    # if save:
    #     plt.savefig('./latent_space_epoch'+str(epoch)+'.png')
    return z
# ---------------------------------------------------------------------------------------------------

# ----------------------------------------- FIND OPTIMAL LR  ----------------------------------------
class LRFinder:
    """
    Cyclical LR, code tailored from:
    https://towardsdatascience.com/estimating-optimal-learning-rate-for-a-deep-neural-network-ce32f2556ce0
    """

    def __init__(self, model):
        self.model = model
        self.losses = []
        self.lrs = []
        self.best_loss = 1e9

    def on_batch_end(self, batch, logs):
        # Log the learning rate
        lr = K.get_value(self.model.optimizer.lr)
        self.lrs.append(lr)

        # Log the loss
        loss = logs['loss']
        self.losses.append(loss)

        # Check whether the loss got too large or NaN
        if batch > 5 and (math.isnan(loss) or loss > self.best_loss * 4):
            self.model.stop_training = True
            return

        if loss < self.best_loss:
            self.best_loss = loss

        # Increase the learning rate for the next batch
        lr *= self.lr_mult
        K.set_value(self.model.optimizer.lr, lr)

    def find(self, x_train, y_train, start_lr, end_lr, batch_size=64, epochs=1, **kw_fit):
        # If x_train contains data for multiple inputs, use length of the first input.
        # Assumption: the first element in the list is single input; NOT a list of inputs.
        N = x_train[0].shape[0] if isinstance(x_train, list) else x_train.shape[0]

        # Compute number of batches and LR multiplier
        num_batches = epochs * N / batch_size
        self.lr_mult = (float(end_lr) / float(start_lr)) ** (float(1) / float(num_batches))
        # Save weights into a file
        initial_weights = self.model.get_weights()

        # Remember the original learning rate
        original_lr = K.get_value(self.model.optimizer.lr)

        # Set the initial learning rate
        K.set_value(self.model.optimizer.lr, start_lr)

        callback = LambdaCallback(on_batch_end=lambda batch, logs: self.on_batch_end(batch, logs))

        self.model.fit(x_train, y_train,
                       batch_size=batch_size, epochs=epochs,
                       callbacks=[callback],
                       **kw_fit)

        # Restore the weights to the state before model fitting
        self.model.set_weights(initial_weights)

        # Restore the original learning rate
        K.set_value(self.model.optimizer.lr, original_lr)

    def find_generator(self, generator, start_lr, end_lr, epochs=1, steps_per_epoch=None, **kw_fit):
        if steps_per_epoch is None:
            try:
                steps_per_epoch = len(generator)
            except (ValueError, NotImplementedError) as e:
                raise e('`steps_per_epoch=None` is only valid for a'
                        ' generator based on the '
                        '`keras.utils.Sequence`'
                        ' class. Please specify `steps_per_epoch` '
                        'or use the `keras.utils.Sequence` class.')
        self.lr_mult = (float(end_lr) / float(start_lr)) ** (float(1) / float(epochs * steps_per_epoch))

        # Save weights into a file
        initial_weights = self.model.get_weights()

        # Remember the original learning rate
        original_lr = K.get_value(self.model.optimizer.lr)

        # Set the initial learning rate
        K.set_value(self.model.optimizer.lr, start_lr)

        callback = LambdaCallback(on_batch_end=lambda batch,
                                                      logs: self.on_batch_end(batch, logs))

        self.model.fit_generator(generator=generator,
                                 epochs=epochs,
                                 steps_per_epoch=steps_per_epoch,
                                 callbacks=[callback],
                                 **kw_fit)

        # Restore the weights to the state before model fitting
        self.model.set_weights(initial_weights)

        # Restore the original learning rate
        K.set_value(self.model.optimizer.lr, original_lr)

    def plot_loss(self, n_skip_beginning=10, n_skip_end=5, x_scale='log'):
        """
        Plots the loss.
        Parameters:
            n_skip_beginning - number of batches to skip on the left.
            n_skip_end - number of batches to skip on the right.
        """
        plt.ylabel("loss")
        plt.xlabel("learning rate (log scale)")
        plt.plot(self.lrs[n_skip_beginning:-n_skip_end], self.losses[n_skip_beginning:-n_skip_end])
        plt.xscale(x_scale)
        plt.show()

    def plot_loss_change(self, sma=1, n_skip_beginning=10, n_skip_end=5, y_lim=(-0.01, 0.01)):
        """
        Plots rate of change of the loss function.
        Parameters:
            sma - number of batches for simple moving average to smooth out the curve.
            n_skip_beginning - number of batches to skip on the left.
            n_skip_end - number of batches to skip on the right.
            y_lim - limits for the y axis.
        """
        derivatives = self.get_derivatives(sma)[n_skip_beginning:-n_skip_end]
        lrs = self.lrs[n_skip_beginning:-n_skip_end]
        plt.ylabel("rate of loss change")
        plt.xlabel("learning rate (log scale)")
        plt.plot(lrs, derivatives)
        plt.xscale('log')
        plt.ylim(y_lim)
        plt.show()

    def get_derivatives(self, sma):
        assert sma >= 1
        derivatives = [0] * sma
        for i in range(sma, len(self.lrs)):
            derivatives.append((self.losses[i] - self.losses[i - sma]) / sma)
        return derivatives

    def get_best_lr(self, sma, n_skip_beginning=10, n_skip_end=5):
        derivatives = self.get_derivatives(sma)
        best_der_idx = np.argmin(derivatives[n_skip_beginning:-n_skip_end])
        return self.lrs[n_skip_beginning:-n_skip_end][best_der_idx]
# ---------------------------------------------------------------------------------------------------

# --------------------------------------------- RESULTS  --------------------------------------------
def get_model(path):
    saved_VRAE_model = load_model(path, compile=False)
    
    # return encoder, regressor
    return saved_VRAE_model.layers[1], saved_VRAE_model.layers[2]

def evaluate(y_true, y_hat, label='test'):
    mse = mean_squared_error(y_true, y_hat)
    rmse = np.sqrt(mse)
    variance = r2_score(y_true, y_hat)
    print('{} set RMSE:{}, R2:{}'.format(label, rmse, variance))

def score(y_true, y_hat):
  res = 0
  for true, hat in zip(y_true, y_hat):
    subs = hat - true
    if subs < 0:
      res = res + np.exp(-subs/13)[0]-1
    else:
      res = res + np.exp(subs/10)[0]-1
  print("score: ", res)

def results(path, x_train, y_train, x_test, y_test):
    # Get model
    encoder, regressor = get_model(path)
    # Latent space
    train_mu = viz_latent_space(encoder, x_train, y_train)
    test_mu = viz_latent_space(encoder, x_test, y_test)
    # Evaluate
    y_hat_train = regressor.predict(train_mu)
    y_hat_test = regressor.predict(test_mu)

    evaluate(y_train, y_hat_train, 'train')
    evaluate(y_test, y_hat_test, 'test')
    score(y_test, y_hat_test)

# %%
import numpy as np


if __name__ == "__main__":
	# ------------------------------ DATA -----------------------------------
	dataset =  "FD004"
	# sensors to work with: T30, T50, P30, PS30, phi
	sensors =  ['s_2', 's_3', 's_4', 's_7', 's_8', 's_11', 's_12', 's_13', 's_15', 's_17', 's_20', 's_21']
	# windows length
	sequence_length = 30
	# smoothing intensity
	alpha = 0.1
	# max RUL
	threshold = 125
	
	x_train, y_train, x_val, y_val, x_test, y_test = get_data(dataset, sensors, 
	sequence_length, alpha, threshold)
	# -----------------------------------------------------------------------
	
	# ----------------------------- MODEL -----------------------------------
	timesteps = x_train.shape[1]
	input_dim = x_train.shape[2]
	intermediate_dim = 300
	batch_size = 128
	latent_dim = 2
	epochs = 10000
	optimizer = 'adam'
	
	RVE = create_model(timesteps, 
			input_dim, 
			intermediate_dim, 
			batch_size, 
			latent_dim, 
			epochs, 
			optimizer,
			)
	
	# Callbacks for training
	model_callbacks = get_callbacks(RVE, x_train, y_train)
	# -----------------------------------------------------------------------

	# --------------------------- TRAINING ---------------------------------
	results = RVE.fit(x_train, y_train,
			shuffle=True,
			epochs=epochs,
			batch_size=batch_size,
			validation_data= (x_val, y_val),
			callbacks=model_callbacks, verbose=2)
	# -----------------------------------------------------------------------
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 30, 12)]     0           []
#
#  masking_1 (Masking)            (None, 30, 12)       0           ['encoder_input[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 600)         751200      ['masking_1[0][0]']
#  )
#
#  dense_3 (Dense)                (None, 2)            1202        ['bidirectional_1[0][0]']
#
#  dense_4 (Dense)                (None, 2)            1202        ['bidirectional_1[0][0]']
#
#  sampling_1 (Sampling)          (None, 2)            0           ['dense_3[0][0]',
#                                                                   'dense_4[0][0]']
#
# ==================================================================================================
# Total params: 753,604
# Trainable params: 753,604
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "regressor"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_sampling_reg (InputLayer)  [(None, 2)]              0
#
#  dense_5 (Dense)             (None, 200)               600
#
#  reg_output (Dense)          (None, 1)                 201
#
# =================================================================
# Total params: 801
# Trainable params: 801
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10000
#
# Epoch 1: val_loss improved from inf to 176.08997, saving model to ./checkpoints/checkpoint
# 341/341 - 25s - loss: 8163.9648 - kl_loss: 153.2017 - reg_loss: 8010.7661 - val_loss: 176.0900 - val_kl_loss: 73.1377 - val_reg_loss: 102.9523 - 25s/epoch - 74ms/step
# Epoch 2/10000
#
# Epoch 2: val_loss did not improve from 176.08997
# 341/341 - 5s - loss: 6532.0791 - kl_loss: 190.2782 - reg_loss: 6341.7993 - val_loss: 487.4105 - val_kl_loss: 99.0380 - val_reg_loss: 388.3726 - 5s/epoch - 16ms/step
# Epoch 3/10000
#
# Epoch 3: val_loss did not improve from 176.08997
# 341/341 - 5s - loss: 5434.4155 - kl_loss: 178.6767 - reg_loss: 5255.7358 - val_loss: 226.7283 - val_kl_loss: 13.1149 - val_reg_loss: 213.6134 - 5s/epoch - 16ms/step
# Epoch 4/10000
#
# Epoch 4: val_loss did not improve from 176.08997
# 341/341 - 5s - loss: 4601.7642 - kl_loss: 152.8136 - reg_loss: 4448.9517 - val_loss: 208.2976 - val_kl_loss: 6.4293 - val_reg_loss: 201.8683 - 5s/epoch - 16ms/step
# Epoch 5/10000
#
# Epoch 5: val_loss improved from 176.08997 to 95.07373, saving model to ./checkpoints/checkpoint
# 341/341 - 16s - loss: 3915.5247 - kl_loss: 130.2553 - reg_loss: 3785.2698 - val_loss: 95.0737 - val_kl_loss: 3.4682 - val_reg_loss: 91.6055 - 16s/epoch - 46ms/step
# Epoch 6/10000
#
# Epoch 6: val_loss improved from 95.07373 to 63.17778, saving model to ./checkpoints/checkpoint
# 341/341 - 16s - loss: 3319.2397 - kl_loss: 111.9642 - reg_loss: 3207.2769 - val_loss: 63.1778 - val_kl_loss: 2.8745 - val_reg_loss: 60.3033 - 16s/epoch - 46ms/step
# Epoch 7/10000
#
# Epoch 7: val_loss improved from 63.17778 to 48.30386, saving model to ./checkpoints/checkpoint
# 341/341 - 12s - loss: 2810.6284 - kl_loss: 97.3860 - reg_loss: 2713.2422 - val_loss: 48.3039 - val_kl_loss: 2.8180 - val_reg_loss: 45.4859 - 12s/epoch - 35ms/step
# Epoch 8/10000
#
# Epoch 8: val_loss improved from 48.30386 to 22.99195, saving model to ./checkpoints/checkpoint
# 341/341 - 16s - loss: 2366.8040 - kl_loss: 85.4039 - reg_loss: 2281.3982 - val_loss: 22.9919 - val_kl_loss: 3.1874 - val_reg_loss: 19.8045 - 16s/epoch - 47ms/step
# Epoch 9/10000
#
# Epoch 9: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 1979.9990 - kl_loss: 75.4462 - reg_loss: 1904.5538 - val_loss: 62.6926 - val_kl_loss: 3.4190 - val_reg_loss: 59.2736 - 5s/epoch - 16ms/step
# Epoch 10/10000
#
# Epoch 10: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 1656.1450 - kl_loss: 66.7481 - reg_loss: 1589.3958 - val_loss: 158.4421 - val_kl_loss: 3.6345 - val_reg_loss: 154.8076 - 5s/epoch - 16ms/step
# Epoch 11/10000
#
# Epoch 11: val_loss did not improve from 22.99195
# 341/341 - 8s - loss: 1375.2140 - kl_loss: 59.4857 - reg_loss: 1315.7279 - val_loss: 47.1692 - val_kl_loss: 3.6589 - val_reg_loss: 43.5103 - 8s/epoch - 22ms/step
# Epoch 12/10000
#
# Epoch 12: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 1133.2886 - kl_loss: 53.0510 - reg_loss: 1080.2374 - val_loss: 69.4635 - val_kl_loss: 4.1067 - val_reg_loss: 65.3569 - 5s/epoch - 15ms/step
# Epoch 13/10000
#
# Epoch 13: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 928.4295 - kl_loss: 47.4683 - reg_loss: 880.9609 - val_loss: 51.8631 - val_kl_loss: 4.0802 - val_reg_loss: 47.7829 - 5s/epoch - 16ms/step
# Epoch 14/10000
#
# Epoch 14: val_loss did not improve from 22.99195
# 341/341 - 6s - loss: 760.0308 - kl_loss: 42.5302 - reg_loss: 717.5007 - val_loss: 124.9291 - val_kl_loss: 4.6775 - val_reg_loss: 120.2516 - 6s/epoch - 16ms/step
# Epoch 15/10000
#
# Epoch 15: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 620.1846 - kl_loss: 38.0701 - reg_loss: 582.1148 - val_loss: 68.1491 - val_kl_loss: 4.4235 - val_reg_loss: 63.7256 - 5s/epoch - 16ms/step
# Epoch 16/10000
#
# Epoch 16: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 504.3869 - kl_loss: 34.2108 - reg_loss: 470.1758 - val_loss: 91.6674 - val_kl_loss: 4.8766 - val_reg_loss: 86.7908 - 5s/epoch - 16ms/step
# Epoch 17/10000
#
# Epoch 17: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 412.4666 - kl_loss: 30.5949 - reg_loss: 381.8718 - val_loss: 191.9482 - val_kl_loss: 5.1284 - val_reg_loss: 186.8197 - 5s/epoch - 15ms/step
# Epoch 18/10000
#
# Epoch 18: val_loss did not improve from 22.99195
# 341/341 - 7s - loss: 343.6410 - kl_loss: 27.5199 - reg_loss: 316.1212 - val_loss: 303.5842 - val_kl_loss: 5.1401 - val_reg_loss: 298.4441 - 7s/epoch - 20ms/step
# Epoch 19/10000
#
# Epoch 19: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 283.7003 - kl_loss: 24.5198 - reg_loss: 259.1806 - val_loss: 69.2367 - val_kl_loss: 5.2839 - val_reg_loss: 63.9528 - 5s/epoch - 16ms/step
# Epoch 20/10000
#
# Epoch 20: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 240.3320 - kl_loss: 22.1054 - reg_loss: 218.2264 - val_loss: 136.6360 - val_kl_loss: 5.6573 - val_reg_loss: 130.9787 - 5s/epoch - 15ms/step
# Epoch 21/10000
#
# Epoch 21: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 214.0302 - kl_loss: 19.8574 - reg_loss: 194.1727 - val_loss: 46.5536 - val_kl_loss: 5.6621 - val_reg_loss: 40.8914 - 5s/epoch - 16ms/step
# Epoch 22/10000
#
# Epoch 22: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 186.1185 - kl_loss: 17.9851 - reg_loss: 168.1333 - val_loss: 206.3083 - val_kl_loss: 5.9134 - val_reg_loss: 200.3949 - 5s/epoch - 16ms/step
# Epoch 23/10000
#
# Epoch 23: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 169.0097 - kl_loss: 16.4177 - reg_loss: 152.5920 - val_loss: 41.1227 - val_kl_loss: 5.6457 - val_reg_loss: 35.4770 - 5s/epoch - 15ms/step
# Epoch 24/10000
#
# Epoch 24: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 174.2737 - kl_loss: 14.6916 - reg_loss: 159.5821 - val_loss: 43.4065 - val_kl_loss: 6.0549 - val_reg_loss: 37.3515 - 5s/epoch - 15ms/step
# Epoch 25/10000
#
# Epoch 25: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 151.6951 - kl_loss: 13.6419 - reg_loss: 138.0531 - val_loss: 73.0078 - val_kl_loss: 5.9268 - val_reg_loss: 67.0810 - 5s/epoch - 16ms/step
# Epoch 26/10000
#
# Epoch 26: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 141.8944 - kl_loss: 12.6370 - reg_loss: 129.2573 - val_loss: 112.0225 - val_kl_loss: 6.0085 - val_reg_loss: 106.0141 - 5s/epoch - 15ms/step
# Epoch 27/10000
#
# Epoch 27: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 136.2393 - kl_loss: 11.8288 - reg_loss: 124.4106 - val_loss: 42.9286 - val_kl_loss: 6.0337 - val_reg_loss: 36.8948 - 5s/epoch - 16ms/step
# Epoch 28/10000
#
# Epoch 28: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 129.3259 - kl_loss: 11.0917 - reg_loss: 118.2342 - val_loss: 104.6413 - val_kl_loss: 6.1011 - val_reg_loss: 98.5402 - 5s/epoch - 16ms/step
# Epoch 29/10000
#
# Epoch 29: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 125.9381 - kl_loss: 10.5763 - reg_loss: 115.3618 - val_loss: 134.0186 - val_kl_loss: 6.4804 - val_reg_loss: 127.5382 - 5s/epoch - 15ms/step
# Epoch 30/10000
#
# Epoch 30: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 121.6156 - kl_loss: 10.2119 - reg_loss: 111.4036 - val_loss: 75.3852 - val_kl_loss: 6.2885 - val_reg_loss: 69.0968 - 5s/epoch - 16ms/step
# Epoch 31/10000
#
# Epoch 31: val_loss did not improve from 22.99195
# 341/341 - 5s - loss: 122.8233 - kl_loss: 9.9860 - reg_loss: 112.8374 - val_loss: 134.2732 - val_kl_loss: 6.2748 - val_reg_loss: 127.9984 - 5s/epoch - 15ms/step
# Epoch 32/10000
#
# Epoch 32: val_loss improved from 22.99195 to 18.34692, saving model to ./checkpoints/checkpoint
# 341/341 - 16s - loss: 113.3475 - kl_loss: 9.6431 - reg_loss: 103.7043 - val_loss: 18.3469 - val_kl_loss: 6.2540 - val_reg_loss: 12.0930 - 16s/epoch - 45ms/step
# Epoch 33/10000
#
# Epoch 33: val_loss did not improve from 18.34692
# 341/341 - 5s - loss: 113.6541 - kl_loss: 9.4948 - reg_loss: 104.1592 - val_loss: 81.9781 - val_kl_loss: 6.3687 - val_reg_loss: 75.6094 - 5s/epoch - 16ms/step
# Epoch 34/10000
#
# Epoch 34: val_loss did not improve from 18.34692
# 341/341 - 5s - loss: 102.1915 - kl_loss: 9.1928 - reg_loss: 92.9986 - val_loss: 27.2149 - val_kl_loss: 6.3754 - val_reg_loss: 20.8396 - 5s/epoch - 16ms/step
# Epoch 35/10000
#
# Epoch 35: val_loss improved from 18.34692 to 14.19490, saving model to ./checkpoints/checkpoint
# 341/341 - 16s - loss: 101.4201 - kl_loss: 9.0493 - reg_loss: 92.3708 - val_loss: 14.1949 - val_kl_loss: 6.4157 - val_reg_loss: 7.7792 - 16s/epoch - 46ms/step
# Epoch 36/10000
#
# Epoch 36: val_loss did not improve from 14.19490
# 341/341 - 5s - loss: 103.0701 - kl_loss: 8.8649 - reg_loss: 94.2052 - val_loss: 20.7927 - val_kl_loss: 6.4971 - val_reg_loss: 14.2955 - 5s/epoch - 15ms/step
# Epoch 37/10000
#
# Epoch 37: val_loss did not improve from 14.19490
# 341/341 - 5s - loss: 92.3881 - kl_loss: 8.8285 - reg_loss: 83.5597 - val_loss: 87.4468 - val_kl_loss: 6.4132 - val_reg_loss: 81.0336 - 5s/epoch - 16ms/step
# Epoch 38/10000
#
# Epoch 38: val_loss did not improve from 14.19490
# 341/341 - 5s - loss: 85.8811 - kl_loss: 8.7914 - reg_loss: 77.0896 - val_loss: 129.9135 - val_kl_loss: 6.5541 - val_reg_loss: 123.3594 - 5s/epoch - 15ms/step
# Epoch 39/10000
#
# Epoch 39: val_loss did not improve from 14.19490
# 341/341 - 5s - loss: 82.0087 - kl_loss: 8.6916 - reg_loss: 73.3172 - val_loss: 22.4809 - val_kl_loss: 6.6262 - val_reg_loss: 15.8547 - 5s/epoch - 16ms/step
# Epoch 40/10000
#
# Epoch 40: val_loss did not improve from 14.19490
# 341/341 - 6s - loss: 77.1763 - kl_loss: 8.6361 - reg_loss: 68.5402 - val_loss: 102.4399 - val_kl_loss: 6.6337 - val_reg_loss: 95.8062 - 6s/epoch - 17ms/step
# Epoch 41/10000
#
# Epoch 41: val_loss did not improve from 14.19490
# 341/341 - 6s - loss: 82.6012 - kl_loss: 8.4677 - reg_loss: 74.1335 - val_loss: 42.1074 - val_kl_loss: 6.8350 - val_reg_loss: 35.2724 - 6s/epoch - 19ms/step
# Epoch 42/10000
#
# Epoch 42: val_loss did not improve from 14.19490
# 341/341 - 5s - loss: 72.9660 - kl_loss: 8.4598 - reg_loss: 64.5062 - val_loss: 80.1921 - val_kl_loss: 6.8501 - val_reg_loss: 73.3420 - 5s/epoch - 15ms/step
# Epoch 43/10000
#
# Epoch 43: val_loss did not improve from 14.19490
# 341/341 - 5s - loss: 66.0983 - kl_loss: 8.4068 - reg_loss: 57.6915 - val_loss: 102.0254 - val_kl_loss: 6.6998 - val_reg_loss: 95.3256 - 5s/epoch - 16ms/step
# Epoch 44/10000
#
# Epoch 44: val_loss did not improve from 14.19490
# 341/341 - 5s - loss: 62.6368 - kl_loss: 8.3492 - reg_loss: 54.2876 - val_loss: 18.6652 - val_kl_loss: 6.6579 - val_reg_loss: 12.0073 - 5s/epoch - 15ms/step
# Epoch 45/10000
#
# Epoch 45: val_loss did not improve from 14.19490
# 341/341 - 6s - loss: 60.2784 - kl_loss: 8.2543 - reg_loss: 52.0241 - val_loss: 40.1846 - val_kl_loss: 6.6013 - val_reg_loss: 33.5832 - 6s/epoch - 16ms/step
# Epoch 46/10000
#
# Epoch 46: val_loss did not improve from 14.19490
# 341/341 - 6s - loss: 54.5478 - kl_loss: 8.2441 - reg_loss: 46.3037 - val_loss: 60.6667 - val_kl_loss: 6.8197 - val_reg_loss: 53.8471 - 6s/epoch - 17ms/step
# Epoch 47/10000
#
# Epoch 47: val_loss did not improve from 14.19490
# 341/341 - 6s - loss: 51.4659 - kl_loss: 8.2453 - reg_loss: 43.2206 - val_loss: 20.8355 - val_kl_loss: 6.8121 - val_reg_loss: 14.0234 - 6s/epoch - 16ms/step
# Epoch 48/10000
#
# Epoch 48: val_loss improved from 14.19490 to 12.04091, saving model to ./checkpoints/checkpoint
# 341/341 - 12s - loss: 52.7625 - kl_loss: 8.1706 - reg_loss: 44.5919 - val_loss: 12.0409 - val_kl_loss: 7.2852 - val_reg_loss: 4.7557 - 12s/epoch - 36ms/step
# Epoch 49/10000
#
# Epoch 49: val_loss did not improve from 12.04091
# 341/341 - 6s - loss: 50.1638 - kl_loss: 8.1661 - reg_loss: 41.9977 - val_loss: 33.3142 - val_kl_loss: 6.7829 - val_reg_loss: 26.5312 - 6s/epoch - 16ms/step
# Epoch 50/10000
#
# Epoch 50: val_loss did not improve from 12.04091
# 341/341 - 7s - loss: 47.8753 - kl_loss: 8.1398 - reg_loss: 39.7355 - val_loss: 19.2060 - val_kl_loss: 7.1164 - val_reg_loss: 12.0896 - 7s/epoch - 20ms/step
# Epoch 51/10000
#
# Epoch 51: val_loss did not improve from 12.04091
# 341/341 - 6s - loss: 42.3030 - kl_loss: 8.0978 - reg_loss: 34.2052 - val_loss: 23.3822 - val_kl_loss: 6.9014 - val_reg_loss: 16.4808 - 6s/epoch - 16ms/step
# Epoch 52/10000
#
# Epoch 52: val_loss did not improve from 12.04091
# 341/341 - 6s - loss: 38.1007 - kl_loss: 8.0295 - reg_loss: 30.0712 - val_loss: 24.1523 - val_kl_loss: 7.0653 - val_reg_loss: 17.0870 - 6s/epoch - 17ms/step
# Epoch 53/10000
#
# Epoch 53: val_loss did not improve from 12.04091
# 341/341 - 5s - loss: 37.2566 - kl_loss: 8.0321 - reg_loss: 29.2245 - val_loss: 18.4106 - val_kl_loss: 7.1916 - val_reg_loss: 11.2190 - 5s/epoch - 16ms/step
# Epoch 54/10000
#
# Epoch 54: val_loss did not improve from 12.04091
# 341/341 - 6s - loss: 33.7245 - kl_loss: 8.0181 - reg_loss: 25.7064 - val_loss: 15.1138 - val_kl_loss: 7.2165 - val_reg_loss: 7.8973 - 6s/epoch - 16ms/step
# Epoch 55/10000
#
# Epoch 55: val_loss did not improve from 12.04091
# 341/341 - 6s - loss: 47.6406 - kl_loss: 8.0324 - reg_loss: 39.6082 - val_loss: 25.6769 - val_kl_loss: 7.3404 - val_reg_loss: 18.3365 - 6s/epoch - 16ms/step
# Epoch 56/10000
#
# Epoch 56: val_loss did not improve from 12.04091
# 341/341 - 6s - loss: 42.8128 - kl_loss: 7.9811 - reg_loss: 34.8317 - val_loss: 48.3294 - val_kl_loss: 7.0340 - val_reg_loss: 41.2954 - 6s/epoch - 16ms/step
# Epoch 57/10000
#
# Epoch 57: val_loss did not improve from 12.04091
# 341/341 - 5s - loss: 34.8983 - kl_loss: 7.9865 - reg_loss: 26.9118 - val_loss: 62.1181 - val_kl_loss: 7.3222 - val_reg_loss: 54.7958 - 5s/epoch - 16ms/step
# Epoch 58/10000
#
# Epoch 58: val_loss improved from 12.04091 to 10.69906, saving model to ./checkpoints/checkpoint
# 341/341 - 16s - loss: 33.5948 - kl_loss: 7.9481 - reg_loss: 25.6467 - val_loss: 10.6991 - val_kl_loss: 7.5030 - val_reg_loss: 3.1960 - 16s/epoch - 46ms/step
# Epoch 59/10000
#
# Epoch 59: val_loss improved from 10.69906 to 10.43022, saving model to ./checkpoints/checkpoint
# 341/341 - 16s - loss: 30.5101 - kl_loss: 7.9123 - reg_loss: 22.5979 - val_loss: 10.4302 - val_kl_loss: 7.2640 - val_reg_loss: 3.1662 - 16s/epoch - 46ms/step
# Epoch 60/10000
#
# Epoch 60: val_loss did not improve from 10.43022
# 341/341 - 6s - loss: 27.8936 - kl_loss: 7.8384 - reg_loss: 20.0553 - val_loss: 18.6700 - val_kl_loss: 7.3443 - val_reg_loss: 11.3257 - 6s/epoch - 16ms/step
# Epoch 61/10000
#
# Epoch 61: val_loss improved from 10.43022 to 9.03927, saving model to ./checkpoints/checkpoint
# 341/341 - 17s - loss: 25.4458 - kl_loss: 7.8236 - reg_loss: 17.6222 - val_loss: 9.0393 - val_kl_loss: 7.4352 - val_reg_loss: 1.6041 - 17s/epoch - 51ms/step
# Epoch 62/10000
#
# Epoch 62: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 42.6530 - kl_loss: 7.8052 - reg_loss: 34.8478 - val_loss: 66.9037 - val_kl_loss: 7.3234 - val_reg_loss: 59.5803 - 5s/epoch - 15ms/step
# Epoch 63/10000
#
# Epoch 63: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 32.2587 - kl_loss: 7.7723 - reg_loss: 24.4864 - val_loss: 15.1469 - val_kl_loss: 7.4851 - val_reg_loss: 7.6618 - 5s/epoch - 15ms/step
# Epoch 64/10000
#
# Epoch 64: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 26.7580 - kl_loss: 7.8038 - reg_loss: 18.9541 - val_loss: 11.4855 - val_kl_loss: 7.5743 - val_reg_loss: 3.9113 - 5s/epoch - 16ms/step
# Epoch 65/10000
#
# Epoch 65: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 20.9238 - kl_loss: 7.8128 - reg_loss: 13.1109 - val_loss: 17.0644 - val_kl_loss: 7.5182 - val_reg_loss: 9.5462 - 5s/epoch - 16ms/step
# Epoch 66/10000
#
# Epoch 66: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 22.2577 - kl_loss: 7.7423 - reg_loss: 14.5154 - val_loss: 19.2675 - val_kl_loss: 7.4475 - val_reg_loss: 11.8200 - 5s/epoch - 15ms/step
# Epoch 67/10000
#
# Epoch 67: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 20.8700 - kl_loss: 7.7047 - reg_loss: 13.1652 - val_loss: 11.4185 - val_kl_loss: 7.5026 - val_reg_loss: 3.9159 - 5s/epoch - 15ms/step
# Epoch 68/10000
#
# Epoch 68: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 26.8232 - kl_loss: 7.7177 - reg_loss: 19.1055 - val_loss: 13.8227 - val_kl_loss: 7.7132 - val_reg_loss: 6.1096 - 5s/epoch - 15ms/step
# Epoch 69/10000
#
# Epoch 69: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 21.4042 - kl_loss: 7.7187 - reg_loss: 13.6855 - val_loss: 11.1484 - val_kl_loss: 7.5176 - val_reg_loss: 3.6308 - 5s/epoch - 16ms/step
# Epoch 70/10000
#
# Epoch 70: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 20.2558 - kl_loss: 7.6693 - reg_loss: 12.5865 - val_loss: 9.9749 - val_kl_loss: 7.4173 - val_reg_loss: 2.5576 - 5s/epoch - 15ms/step
# Epoch 71/10000
#
# Epoch 71: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 28.5867 - kl_loss: 7.6413 - reg_loss: 20.9454 - val_loss: 16.0593 - val_kl_loss: 6.9203 - val_reg_loss: 9.1390 - 5s/epoch - 16ms/step
# Epoch 72/10000
#
# Epoch 72: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 36.8859 - kl_loss: 7.6139 - reg_loss: 29.2720 - val_loss: 18.7366 - val_kl_loss: 7.1590 - val_reg_loss: 11.5776 - 5s/epoch - 15ms/step
# Epoch 73/10000
#
# Epoch 73: val_loss did not improve from 9.03927
# 341/341 - 6s - loss: 30.1041 - kl_loss: 7.6218 - reg_loss: 22.4824 - val_loss: 26.6077 - val_kl_loss: 7.8853 - val_reg_loss: 18.7224 - 6s/epoch - 16ms/step
# Epoch 74/10000
#
# Epoch 74: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 26.0423 - kl_loss: 7.5986 - reg_loss: 18.4437 - val_loss: 13.9328 - val_kl_loss: 7.9723 - val_reg_loss: 5.9605 - 5s/epoch - 16ms/step
# Epoch 75/10000
#
# Epoch 75: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 26.2016 - kl_loss: 7.5968 - reg_loss: 18.6047 - val_loss: 12.5444 - val_kl_loss: 7.6418 - val_reg_loss: 4.9026 - 5s/epoch - 15ms/step
# Epoch 76/10000
#
# Epoch 76: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 21.3078 - kl_loss: 7.5358 - reg_loss: 13.7719 - val_loss: 18.6267 - val_kl_loss: 7.5645 - val_reg_loss: 11.0623 - 5s/epoch - 15ms/step
# Epoch 77/10000
#
# Epoch 77: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 17.5893 - kl_loss: 7.5355 - reg_loss: 10.0539 - val_loss: 19.3350 - val_kl_loss: 7.6343 - val_reg_loss: 11.7006 - 5s/epoch - 16ms/step
# Epoch 78/10000
#
# Epoch 78: val_loss did not improve from 9.03927
# 341/341 - 5s - loss: 17.0281 - kl_loss: 7.5264 - reg_loss: 9.5017 - val_loss: 12.4951 - val_kl_loss: 7.6694 - val_reg_loss: 4.8258 - 5s/epoch - 15ms/step
# Epoch 79/10000
#
# Epoch 79: val_loss improved from 9.03927 to 9.00230, saving model to ./checkpoints/checkpoint
# 341/341 - 16s - loss: 16.3966 - kl_loss: 7.4849 - reg_loss: 8.9117 - val_loss: 9.0023 - val_kl_loss: 7.6319 - val_reg_loss: 1.3704 - 16s/epoch - 46ms/step
# Epoch 80/10000
#
# Epoch 80: val_loss did not improve from 9.00230
# 341/341 - 5s - loss: 16.2832 - kl_loss: 7.4890 - reg_loss: 8.7941 - val_loss: 13.0230 - val_kl_loss: 7.6890 - val_reg_loss: 5.3340 - 5s/epoch - 16ms/step
# Epoch 81/10000
#
# Epoch 81: val_loss did not improve from 9.00230
# 341/341 - 5s - loss: 21.0606 - kl_loss: 7.4708 - reg_loss: 13.5898 - val_loss: 10.1317 - val_kl_loss: 7.4496 - val_reg_loss: 2.6821 - 5s/epoch - 16ms/step
# Epoch 82/10000
#
# Epoch 82: val_loss did not improve from 9.00230
# 341/341 - 5s - loss: 15.0021 - kl_loss: 7.4703 - reg_loss: 7.5318 - val_loss: 10.5342 - val_kl_loss: 7.5726 - val_reg_loss: 2.9615 - 5s/epoch - 16ms/step
# Epoch 83/10000
#
# Epoch 83: val_loss improved from 9.00230 to 8.37312, saving model to ./checkpoints/checkpoint
# 341/341 - 18s - loss: 17.1128 - kl_loss: 7.4634 - reg_loss: 9.6494 - val_loss: 8.3731 - val_kl_loss: 7.6133 - val_reg_loss: 0.7598 - 18s/epoch - 51ms/step
# Epoch 84/10000
#
# Epoch 84: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 15.6018 - kl_loss: 7.4196 - reg_loss: 8.1823 - val_loss: 11.8928 - val_kl_loss: 7.6229 - val_reg_loss: 4.2698 - 5s/epoch - 16ms/step
# Epoch 85/10000
#
# Epoch 85: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 14.8100 - kl_loss: 7.3776 - reg_loss: 7.4324 - val_loss: 9.4458 - val_kl_loss: 7.5239 - val_reg_loss: 1.9219 - 5s/epoch - 16ms/step
# Epoch 86/10000
#
# Epoch 86: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 29.8184 - kl_loss: 7.3758 - reg_loss: 22.4426 - val_loss: 24.7478 - val_kl_loss: 7.3331 - val_reg_loss: 17.4148 - 5s/epoch - 16ms/step
# Epoch 87/10000
#
# Epoch 87: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 16.4282 - kl_loss: 7.3223 - reg_loss: 9.1059 - val_loss: 15.8172 - val_kl_loss: 7.7381 - val_reg_loss: 8.0791 - 5s/epoch - 15ms/step
# Epoch 88/10000
#
# Epoch 88: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 27.0503 - kl_loss: 7.3800 - reg_loss: 19.6703 - val_loss: 10.2665 - val_kl_loss: 7.7355 - val_reg_loss: 2.5310 - 5s/epoch - 16ms/step
# Epoch 89/10000
#
# Epoch 89: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 24.5715 - kl_loss: 7.3003 - reg_loss: 17.2712 - val_loss: 35.3762 - val_kl_loss: 7.8813 - val_reg_loss: 27.4949 - 5s/epoch - 16ms/step
# Epoch 90/10000
#
# Epoch 90: val_loss did not improve from 8.37312
# 341/341 - 6s - loss: 16.0500 - kl_loss: 7.3285 - reg_loss: 8.7215 - val_loss: 14.9427 - val_kl_loss: 7.9090 - val_reg_loss: 7.0337 - 6s/epoch - 16ms/step
# Epoch 91/10000
#
# Epoch 91: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 13.0781 - kl_loss: 7.3074 - reg_loss: 5.7707 - val_loss: 9.9498 - val_kl_loss: 7.9277 - val_reg_loss: 2.0221 - 5s/epoch - 15ms/step
# Epoch 92/10000
#
# Epoch 92: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 13.6946 - kl_loss: 7.3096 - reg_loss: 6.3850 - val_loss: 16.4519 - val_kl_loss: 7.9371 - val_reg_loss: 8.5148 - 5s/epoch - 15ms/step
# Epoch 93/10000
#
# Epoch 93: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 12.7691 - kl_loss: 7.3024 - reg_loss: 5.4667 - val_loss: 9.9544 - val_kl_loss: 7.9290 - val_reg_loss: 2.0253 - 5s/epoch - 16ms/step
# Epoch 94/10000
#
# Epoch 94: val_loss did not improve from 8.37312
# 341/341 - 6s - loss: 13.8034 - kl_loss: 7.2904 - reg_loss: 6.5131 - val_loss: 21.4724 - val_kl_loss: 7.8552 - val_reg_loss: 13.6172 - 6s/epoch - 16ms/step
# Epoch 95/10000
#
# Epoch 95: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 21.9332 - kl_loss: 7.2586 - reg_loss: 14.6745 - val_loss: 12.0265 - val_kl_loss: 7.7868 - val_reg_loss: 4.2397 - 5s/epoch - 16ms/step
# Epoch 96/10000
#
# Epoch 96: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 13.4402 - kl_loss: 7.2513 - reg_loss: 6.1889 - val_loss: 10.6079 - val_kl_loss: 7.8169 - val_reg_loss: 2.7909 - 5s/epoch - 16ms/step
# Epoch 97/10000
#
# Epoch 97: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 12.8381 - kl_loss: 7.2333 - reg_loss: 5.6048 - val_loss: 12.9479 - val_kl_loss: 7.9226 - val_reg_loss: 5.0253 - 5s/epoch - 15ms/step
# Epoch 98/10000
#
# Epoch 98: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 13.8363 - kl_loss: 7.2268 - reg_loss: 6.6095 - val_loss: 9.2882 - val_kl_loss: 8.0112 - val_reg_loss: 1.2769 - 5s/epoch - 16ms/step
# Epoch 99/10000
#
# Epoch 99: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 12.6546 - kl_loss: 7.2419 - reg_loss: 5.4127 - val_loss: 14.6744 - val_kl_loss: 8.0499 - val_reg_loss: 6.6244 - 5s/epoch - 15ms/step
# Epoch 100/10000
#
# Epoch 100: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 14.0010 - kl_loss: 7.2026 - reg_loss: 6.7984 - val_loss: 9.5691 - val_kl_loss: 7.9294 - val_reg_loss: 1.6397 - 5s/epoch - 16ms/step
# Epoch 101/10000
#
# Epoch 101: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 12.5018 - kl_loss: 7.1999 - reg_loss: 5.3020 - val_loss: 8.5136 - val_kl_loss: 7.8299 - val_reg_loss: 0.6836 - 5s/epoch - 16ms/step
# Epoch 102/10000
#
# Epoch 102: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 14.6623 - kl_loss: 7.1932 - reg_loss: 7.4691 - val_loss: 18.4801 - val_kl_loss: 7.9736 - val_reg_loss: 10.5066 - 5s/epoch - 15ms/step
# Epoch 103/10000
#
# Epoch 103: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 12.2002 - kl_loss: 7.1846 - reg_loss: 5.0156 - val_loss: 12.0837 - val_kl_loss: 8.0090 - val_reg_loss: 4.0747 - 5s/epoch - 15ms/step
# Epoch 104/10000
#
# Epoch 104: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 32.0122 - kl_loss: 7.1050 - reg_loss: 24.9072 - val_loss: 15.9761 - val_kl_loss: 7.8251 - val_reg_loss: 8.1510 - 5s/epoch - 16ms/step
# Epoch 105/10000
#
# Epoch 105: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 21.1274 - kl_loss: 7.1390 - reg_loss: 13.9884 - val_loss: 17.6971 - val_kl_loss: 8.2536 - val_reg_loss: 9.4435 - 5s/epoch - 16ms/step
# Epoch 106/10000
#
# Epoch 106: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 16.9355 - kl_loss: 7.1134 - reg_loss: 9.8221 - val_loss: 55.2575 - val_kl_loss: 8.6577 - val_reg_loss: 46.5998 - 5s/epoch - 16ms/step
# Epoch 107/10000
#
# Epoch 107: val_loss did not improve from 8.37312
# 341/341 - 7s - loss: 13.3688 - kl_loss: 7.1269 - reg_loss: 6.2419 - val_loss: 9.3010 - val_kl_loss: 8.4448 - val_reg_loss: 0.8562 - 7s/epoch - 21ms/step
# Epoch 108/10000
#
# Epoch 108: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 11.2133 - kl_loss: 7.1083 - reg_loss: 4.1050 - val_loss: 11.1788 - val_kl_loss: 8.3565 - val_reg_loss: 2.8223 - 5s/epoch - 15ms/step
# Epoch 109/10000
#
# Epoch 109: val_loss did not improve from 8.37312
# 341/341 - 6s - loss: 11.2806 - kl_loss: 7.0923 - reg_loss: 4.1883 - val_loss: 13.4101 - val_kl_loss: 8.3699 - val_reg_loss: 5.0402 - 6s/epoch - 16ms/step
# Epoch 110/10000
#
# Epoch 110: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 11.5738 - kl_loss: 7.0840 - reg_loss: 4.4898 - val_loss: 10.9188 - val_kl_loss: 8.3597 - val_reg_loss: 2.5591 - 5s/epoch - 15ms/step
# Epoch 111/10000
#
# Epoch 111: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 11.5611 - kl_loss: 7.0892 - reg_loss: 4.4719 - val_loss: 8.8160 - val_kl_loss: 8.2830 - val_reg_loss: 0.5330 - 5s/epoch - 16ms/step
# Epoch 112/10000
#
# Epoch 112: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 11.7039 - kl_loss: 7.0776 - reg_loss: 4.6263 - val_loss: 10.5906 - val_kl_loss: 8.1994 - val_reg_loss: 2.3912 - 5s/epoch - 16ms/step
# Epoch 113/10000
#
# Epoch 113: val_loss did not improve from 8.37312
# 341/341 - 5s - loss: 11.3735 - kl_loss: 7.0231 - reg_loss: 4.3504 - val_loss: 9.4528 - val_kl_loss: 8.1471 - val_reg_loss: 1.3057 - 5s/epoch - 15ms/step
# Epoch 113: early stopping

# %%
	# -------------------------- EVALUATION ---------------------------------
	RVE.load_weights('./checkpoints/checkpoint')
	train_mu = viz_latent_space(RVE.encoder, np.concatenate((x_train, x_val)), np.concatenate((y_train, y_val)))
	test_mu = viz_latent_space(RVE.encoder, x_test, y_test.clip(upper=threshold))
	# Evaluate
	y_hat_train = RVE.regressor.predict(train_mu)
	y_hat_test = RVE.regressor.predict(test_mu)

	evaluate(np.concatenate((y_train, y_val)), y_hat_train, 'train')
	evaluate(y_test, y_hat_test, 'test')
	# -----------------------------------------------------------------------
# Out:
# train set RMSE:9.306734085083008, R2:0.9496610544625861
# test set RMSE:28.305464079456453, R2:0.7304940018254737

# %%
y_actual = y_test.tolist()
y_pred=y_hat_test.tolist()

index=[]
for i in range (len(y_actual)):
    index.append(i)
    
plt.figure(figsize=(16,5))

plt.plot(index,y_actual,color='red',linestyle='dashed')

plt.plot(index,y_pred,color='blue')

plt.ylabel('RUL')

plt.xlabel('unit_id')

plt.title('Actual vs Predicted')

plt.legend(['Actual','Predicted'])

# %% [markdown]
# ## Custom code
# 개별 unit에 대해 sequence마다 예측한 RUL + Plotting
#
# 단 FD002, FD004에 대해서는 안돌아감
# -> 원인 : cycle이 30보다 작은 unit은 sequence가 생성되지 않기때문

# %%
dir_path = './drive/MyDrive/CMaps/'
train_file = 'train_'+dataset+'.txt'
test_file = 'test_'+dataset+'.txt'
    # columns
index_names = ['unit_nr', 'time_cycles']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names = ['s_{}'.format(i+1) for i in range(0,21)]
col_names = index_names + setting_names + sensor_names
    # data readout
train = pd.read_csv((dir_path+train_file), sep=r'\s+', header=None, 
					 names=col_names)
test = pd.read_csv((dir_path+test_file), sep=r'\s+', header=None, 
					 names=col_names)
y_test = pd.read_csv((dir_path+'RUL_'+dataset+'.txt'), sep=r'\s+', header=None, 
					 names=['RemainingUsefulLife'])
    # create RUL values according to the piece-wise target function
train = add_remaining_useful_life(train)
train['RUL'].clip(upper=threshold, inplace=True)

our_train = train.copy()
a = test.groupby(by="unit_nr")["time_cycles"].max()
index = a.index
b = y_test['RemainingUsefulLife'].tolist()
bb = pd.Series(b, index);c = a+ bb
result_frame = test.merge(c.to_frame(name='max_cycle'), left_on='unit_nr', right_index=True)
rruull = result_frame["max_cycle"] - result_frame["time_cycles"]
result_frame["RUL"] = rruull
result_frame = result_frame.drop("max_cycle", axis=1)

drop_sensors = [element for element in sensor_names if element not in sensors]

our_train_pre = add_operating_condition(our_train.drop(drop_sensors, axis=1))
our_test_pre = add_operating_condition(result_frame.drop(drop_sensors, axis=1))
our_train_pre, our_test_pre = condition_scaler(our_train_pre, our_test_pre, sensors)
  
our_train_pre = exponential_smoothing(our_train_pre, sensors, 0 ,alpha)
our_test_pre = exponential_smoothing(our_test_pre, sensors, 0, alpha)

def everything(our_test, our_y,id) : 
  RVE.load_weights('./checkpoints/checkpoint')
  test_mu = viz_latent_space(RVE.encoder, our_test, our_y.clip(max=threshold))
	# Evaluate
  y_hat_test = RVE.regressor.predict(test_mu)

  evaluate(our_y, y_hat_test, 'test')

  y_actual = our_y.tolist()
  y_pred=y_hat_test.tolist()

  index=[]
  for i in range (len(y_actual)):
    index.append(i)
    
  return index, y_actual, y_pred

threshold = 125
plt.figure(figsize=(48,150))
n=1
for id in (our_test_pre['unit_nr'].unique()):
  L = np.array([id])
  our_test = gen_data_wrapper(our_test_pre, sequence_length, sensors, L)
  our_y = gen_label_wrapper(our_test_pre, sequence_length, ['RUL'],L)
  index, y_actual, y_pred = everything(our_test, our_y,id)

  ax = plt.subplot(34,3,n)
  plt.xlabel('unit_'+str(id))
  ax.set_ylim(0,500)
  ax.plot(index,y_actual)
  ax.plot(index,y_pred)
  n+=1

plt.tight_layout()
plt.show()
# Out:
# test set RMSE:43.41874313354492, R2:0.44004339106117796
# test set RMSE:33.863582611083984, R2:0.1049816043086168
# test set RMSE:49.65322494506836, R2:-1.3587112097694534
# test set RMSE:65.36573028564453, R2:-0.600253809834695
# test set RMSE:38.6800651550293, R2:-36.171370451898646
# test set RMSE:33.32637023925781, R2:0.026317831123239044
# test set RMSE:18.928869247436523, R2:-5.890424221754074
# test set RMSE:50.289344787597656, R2:0.36721815499943933
# test set RMSE:125.5466537475586, R2:-1.9088267136296238
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-244-27b85967f0ee> in <module>()
#      61   our_test = gen_data_wrapper(our_test_pre, sequence_length, sensors, L)
#      62   our_y = gen_label_wrapper(our_test_pre, sequence_length, ['RUL'],L)
# ---> 63   index, y_actual, y_pred = everything(our_test, our_y,id)
#      64
#      65   ax = plt.subplot(34,3,n)
#
# <ipython-input-244-27b85967f0ee> in everything(our_test, our_y, id)
#      39 def everything(our_test, our_y,id) :
#      40   RVE.load_weights('./checkpoints/checkpoint')
# ---> 41   test_mu = viz_latent_space(RVE.encoder, our_test, our_y.clip(max=threshold))
#      42         # Evaluate
#      43   y_hat_test = RVE.regressor.predict(test_mu)
#
# <ipython-input-240-58eca64320e4> in viz_latent_space(encoder, data, targets, epoch, save, show)
#     197
#     198 def viz_latent_space(encoder, data, targets=[], epoch='Final', save=False, show=True):
# --> 199     z, _, _  = encoder.predict(data)
#     200     # plt.figure(figsize=(8, 10))
#     201     # if len(targets)>0:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1995             callbacks.on_predict_batch_end(end_step, {'outputs': batch_outputs})
#    1996       if batch_outputs is None:
# -> 1997         raise ValueError('Unexpected result of `predict_function` '
#    1998                          '(Empty batch_outputs). Please use '
#    1999                          '`Model.compile(..., run_eagerly=True)`, or '
#
# ValueError: Unexpected result of `predict_function` (Empty batch_outputs). Please use `Model.compile(..., run_eagerly=True)`, or `tf.config.run_functions_eagerly(True)` for more information of where went wrong, or file a issue/bug to `tf.keras`.

# %% [markdown]
# ## cycle>30

# %%
dir_path = './drive/MyDrive/CMaps/'
train_file = 'train_'+dataset+'.txt'
test_file = 'test_'+dataset+'.txt'
    # columns
index_names = ['unit_nr', 'time_cycles']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names = ['s_{}'.format(i+1) for i in range(0,21)]
col_names = index_names + setting_names + sensor_names
    # data readout
train = pd.read_csv((dir_path+train_file), sep=r'\s+', header=None, 
					 names=col_names)
test = pd.read_csv((dir_path+test_file), sep=r'\s+', header=None, 
					 names=col_names)
y_test = pd.read_csv((dir_path+'RUL_'+dataset+'.txt'), sep=r'\s+', header=None, 
					 names=['RemainingUsefulLife'])
    # create RUL values according to the piece-wise target function
train = add_remaining_useful_life(train)
train['RUL'].clip(upper=threshold, inplace=True)

# %%
a = test.groupby(by="unit_nr")["time_cycles"].max()
index = a.index
result_frame = test.merge(a.to_frame(name='max_cycle'), left_on='unit_nr', right_index=True)

b = test.groupby(by="unit_nr")["time_cycles"].max() #test에서 max cycle min 값은 19
test_unit = test['unit_nr'].unique()
under_30_index = b[b<30].index.tolist() # max cycle이 30보다 작은 unit number
upper_30_index = [x for x in test_unit if x not in under_30_index] # max cycle이 30보다 큰 unit number

temp_x = result_frame[result_frame['max_cycle']>30].drop("max_cycle", axis=1)
drop_indx = [(x-1) for x in under_30_index]
temp_y = y_test.drop(drop_indx, inplace=False)

# %%
b
# Out:
# unit_nr
# 1      230
# 2      153
# 3      141
# 4      208
# 5       51
#       ...
# 244    184
# 245     63
# 246     29
# 247     94
# 248    281
# Name: time_cycles, Length: 248, dtype: int64

# %% [markdown]
# test 41214
#
# under_30 260
#
# upper_30 40954
#
# ---
#
# a = train.groupby(by="unit_nr")["time_cycles"].max() #train에서 max cycle min 값은 128
#
# b = test.groupby(by="unit_nr")["time_cycles"].max() #test에서 max cycle min 값은 19
#
# ---
#
# 원래 unit은 248개
#
# cycle 30 이하 unit은 11개
#
# 남은 unit은 237개

# %%
our_train = train.copy()
a = temp_x.groupby(by="unit_nr")["time_cycles"].max()
index = a.index
b = temp_y['RemainingUsefulLife'].tolist()
bb = pd.Series(b, index)
c = a+ bb
result_frame = temp_x.merge(c.to_frame(name='max_cycle'), left_on='unit_nr', right_index=True)
rruull = result_frame["max_cycle"] - result_frame["time_cycles"]
result_frame["RUL"] = rruull
result_frame = result_frame.drop("max_cycle", axis=1)

drop_sensors = [element for element in sensor_names if element not in sensors]

our_train_pre = add_operating_condition(our_train.drop(drop_sensors, axis=1))
our_test_pre = add_operating_condition(result_frame.drop(drop_sensors, axis=1))
our_train_pre, our_test_pre = condition_scaler(our_train_pre, our_test_pre, sensors)
  
our_train_pre = exponential_smoothing(our_train_pre, sensors, 0 ,alpha)
our_test_pre = exponential_smoothing(our_test_pre, sensors, 0, alpha)


def everything(our_test, our_y,id) : 
  RVE.load_weights('./checkpoints/checkpoint')
  test_mu = viz_latent_space(RVE.encoder, our_test, our_y.clip(max=threshold))
	# Evaluate
  y_hat_test = RVE.regressor.predict(test_mu)

  evaluate(our_y, y_hat_test, 'test')

  y_actual = our_y.tolist()
  y_pred=y_hat_test.tolist()

  index=[]
  for i in range (len(y_actual)):
    index.append(i)
    
  return index, y_actual, y_pred

threshold = 125
plt.figure(figsize=(48,800))
n=1
for id in (our_test_pre['unit_nr'].unique()):
  L = np.array([id])
  our_test = gen_data_wrapper(our_test_pre, sequence_length, sensors, L)
  our_y = gen_label_wrapper(our_test_pre, sequence_length, ['RUL'],L)
  index, y_actual, y_pred = everything(our_test, our_y,id)
  if (n%3==0):
    du = len(our_test_pre['unit_nr'].unique())
  else:
    du = len(our_test_pre['unit_nr'].unique())+1
  ax = plt.subplot(du,3,n)
  plt.xlabel('unit_'+str(id))
  ax.set_ylim(0,500)
  ax.plot(index,y_actual)
  ax.plot(index,y_pred)
  n+=1

plt.show()
# Out:
# test set RMSE:43.3608512878418, R2:0.4415355959776869
# test set RMSE:33.73617172241211, R2:0.11170399797978037
# test set RMSE:49.83797836303711, R2:-1.3762970021291823
# test set RMSE:65.3246841430664, R2:-0.5982451353503373
# test set RMSE:38.273189544677734, R2:-35.39347080293178
# test set RMSE:33.39960861206055, R2:0.022033361424899756
# test set RMSE:18.78163719177246, R2:-5.783651398420334
# test set RMSE:50.22555923461914, R2:0.3688223434166632
# test set RMSE:125.68663787841797, R2:-1.915316852794886
# test set RMSE:54.916439056396484, R2:-11.888099979227771
# test set RMSE:52.40381622314453, R2:0.4326115929453185
# test set RMSE:70.73029327392578, R2:-0.5313442778800761
# test set RMSE:29.78489112854004, R2:-0.9980626125313921
# test set RMSE:18.13888931274414, R2:0.795640183391696
# test set RMSE:153.63006591796875, R2:-5.361778966166608
# test set RMSE:210.64794921875, R2:-4.724014545174718
# test set RMSE:108.72708892822266, R2:-1.9850591724642506
# test set RMSE:24.71595573425293, R2:0.008716525264020003
# test set RMSE:73.19567108154297, R2:-1.148198005780456
# test set RMSE:20.015260696411133, R2:0.7110980604976842
# test set RMSE:19.17270278930664, R2:0.7506156596222741
# test set RMSE:98.9787826538086, R2:-4.591781150590827
# test set RMSE:193.7238006591797, R2:-1.1563383089030843
# test set RMSE:22.7362003326416, R2:-0.667531910852299
# test set RMSE:36.71616744995117, R2:-0.22330012222487272
# test set RMSE:61.889183044433594, R2:-0.3144374184933618
# test set RMSE:108.92924499511719, R2:-2.5597628685672205
# test set RMSE:38.52219772338867, R2:-0.6153409527471432
# test set RMSE:60.85096740722656, R2:0.16727727404278692
# test set RMSE:66.20894622802734, R2:-7.6476240017584765
# test set RMSE:194.81488037109375, R2:-3.1319331248725666
# test set RMSE:78.50011444091797, R2:-0.19269718696262728
# test set RMSE:36.703216552734375, R2:0.04340425992595953
# test set RMSE:152.94131469726562, R2:-1.811001637596513
# test set RMSE:32.2742805480957, R2:-0.3564352455671864
# test set RMSE:133.8915557861328, R2:-5.285745871912506
# test set RMSE:52.479061126708984, R2:0.4116111710353416
# test set RMSE:200.4019012451172, R2:-2.2513699830768608
# test set RMSE:36.639442443847656, R2:0.4490634915512106
# test set RMSE:24.823261260986328, R2:0.1069647854577016
# test set RMSE:165.11477661132812, R2:-1.301831451877888
# test set RMSE:20.60498046875, R2:-1.122826143318445
# test set RMSE:25.370771408081055, R2:-121.6049564906529
# test set RMSE:46.63954544067383, R2:0.3135134409344965
# test set RMSE:47.39860153198242, R2:0.2122624612540741
# test set RMSE:66.1081314086914, R2:0.11911603095199153
# test set RMSE:70.2936782836914, R2:-0.8926971450569521
# test set RMSE:56.23876190185547, R2:-2.2541867725859395
# test set RMSE:39.739810943603516, R2:-21.560752440203586
# test set RMSE:37.824974060058594, R2:-10.897952541322518
# test set RMSE:83.91812133789062, R2:-30.26415390318183
# test set RMSE:72.3149642944336, R2:-10.461818637049936
# test set RMSE:44.180511474609375, R2:-0.027324989462714777
# test set RMSE:31.03376579284668, R2:-0.3656073753422546
# test set RMSE:20.209182739257812, R2:0.7986055954862903
# test set RMSE:29.280141830444336, R2:-162.30032784598214
# test set RMSE:75.26651000976562, R2:-5.050785695909208
# test set RMSE:152.40634155273438, R2:-1.0694663199307666
# test set RMSE:52.96046829223633, R2:0.2439863324750019
# test set RMSE:129.78070068359375, R2:-11.146416054386146
# test set RMSE:66.68087768554688, R2:-0.08264670296065013
# test set RMSE:28.823387145996094, R2:0.5955269790095385
# test set RMSE:57.23755645751953, R2:-7.503927755998365
# test set RMSE:33.868839263916016, R2:0.059755406976190306
# test set RMSE:61.48869705200195, R2:-0.009507999432737169
# test set RMSE:26.906261444091797, R2:0.5088555468743352
# test set RMSE:28.31837272644043, R2:0.6287360188040702
# test set RMSE:67.74638366699219, R2:0.20375210183212022
# test set RMSE:103.047607421875, R2:-15.089105725442629
# test set RMSE:31.955232620239258, R2:0.1489935035843909
# test set RMSE:82.57392120361328, R2:-1.1740779450362857
# test set RMSE:99.29440307617188, R2:-2.907928584688715
# test set RMSE:49.0017204284668, R2:-79.03893828810307
# test set RMSE:39.12308883666992, R2:-1.9434926207597205
# test set RMSE:16.421682357788086, R2:0.4541059163780452
# test set RMSE:54.878684997558594, R2:-0.5043305338594979
# test set RMSE:42.314903259277344, R2:-2.1194268720503104
# test set RMSE:15.56959056854248, R2:-2.0301519571773468
# test set RMSE:22.668243408203125, R2:0.5495184929160899
# test set RMSE:183.68838500976562, R2:-5.7455861337703436
# test set RMSE:72.24352264404297, R2:-16.996987973898214
# test set RMSE:76.42378234863281, R2:-2.3336728572357437
# test set RMSE:89.81201934814453, R2:-0.9120255304058074
# test set RMSE:55.66861343383789, R2:-0.9528400536730623
# test set RMSE:21.345788955688477, R2:0.5561922144653422
# test set RMSE:115.46414184570312, R2:-1.4411934620972136
# test set RMSE:32.25644302368164, R2:-0.5764819859737922
# test set RMSE:19.423574447631836, R2:0.6576449919203636
# test set RMSE:26.477624893188477, R2:-0.1116244081768174
# test set RMSE:124.96695709228516, R2:-5.409058720352503
# test set RMSE:47.35628890991211, R2:-3.6599851538136
# test set RMSE:99.50546264648438, R2:-17.11220171341728
# test set RMSE:22.362388610839844, R2:0.32077904100723054
# test set RMSE:9.746108055114746, R2:-1.3599158862699294
# test set RMSE:20.367477416992188, R2:-0.7727953560164937
# test set RMSE:54.151187896728516, R2:0.1866442118536057
# test set RMSE:27.902645111083984, R2:0.6649924084104302
# test set RMSE:30.628347396850586, R2:0.4001946085186957
# test set RMSE:155.7823944091797, R2:-0.6991035904685012
# test set RMSE:42.851318359375, R2:-0.6376680632033036
# test set RMSE:17.067262649536133, R2:-1.6992259188048169
# test set RMSE:165.44850158691406, R2:-2.168103369784807
# test set RMSE:74.43523406982422, R2:-3.695427241921
# test set RMSE:19.21613311767578, R2:0.47641294818898783
# test set RMSE:92.09099578857422, R2:-6.563657688133097
# test set RMSE:20.940685272216797, R2:-2.846599196344826
# test set RMSE:130.58615112304688, R2:-1.0109368718734908
# test set RMSE:97.45596313476562, R2:-0.16335926730129757
# test set RMSE:23.272945404052734, R2:-0.8676894692901123
# test set RMSE:36.960201263427734, R2:-0.5453128569502039
# test set RMSE:35.488868713378906, R2:0.5768892104003489
# test set RMSE:44.49083709716797, R2:-7.45912102494888
# test set RMSE:20.900379180908203, R2:0.6991384554814662
# test set RMSE:20.61408233642578, R2:-0.10302492324131318
# test set RMSE:20.45529556274414, R2:0.7738275212880494
# test set RMSE:102.54896545410156, R2:-2.186754732632975
# test set RMSE:92.85885620117188, R2:-4.204890257618475
# test set RMSE:42.99795150756836, R2:0.18506140948708116
# test set RMSE:113.83541870117188, R2:-19.082917451833328
# test set RMSE:44.684356689453125, R2:0.4408070803890324
# test set RMSE:84.16426086425781, R2:-1.1040462944935734
# test set RMSE:33.19248580932617, R2:0.6375851211029
# test set RMSE:106.03167724609375, R2:-27.342979204249634
# test set RMSE:64.66896057128906, R2:-3.14785438825567
# test set RMSE:162.98886108398438, R2:-2.8973581445250054
# test set RMSE:90.13703155517578, R2:-15.027656092177207
# test set RMSE:80.87516784667969, R2:-1.9183681809608517
# test set RMSE:49.62480926513672, R2:-2.996140315398961
# test set RMSE:28.029449462890625, R2:-3.658003773393995
# test set RMSE:68.91433715820312, R2:-0.014638698757451163
# test set RMSE:140.36964416503906, R2:-0.4344263033996769
# test set RMSE:35.708683013916016, R2:-20.0182988885267
# test set RMSE:181.82656860351562, R2:-4.7796250391464135
# test set RMSE:90.89186096191406, R2:-1.2480320041463022
# test set RMSE:78.65237426757812, R2:-20.331712254803477
# test set RMSE:97.00941467285156, R2:-5.580998345075056
# test set RMSE:12.982939720153809, R2:-0.264966102127566
# test set RMSE:113.92736053466797, R2:-0.7539195688748299
# test set RMSE:38.7172966003418, R2:-748.5145141601563
# test set RMSE:23.248987197875977, R2:-0.2173772103417797
# test set RMSE:14.653450965881348, R2:0.1479220848283589
# test set RMSE:22.187240600585938, R2:0.21943930075470952
# test set RMSE:73.5541000366211, R2:-5.900773433442119
# test set RMSE:129.47576904296875, R2:-1.3756226089316752
# test set RMSE:53.610164642333984, R2:-0.15238549028322645
# test set RMSE:77.92816162109375, R2:-0.11197937116978451
# test set RMSE:66.18102264404297, R2:-0.9074264411146109
# test set RMSE:102.73065948486328, R2:-11.415986183090965
# test set RMSE:25.933948516845703, R2:0.06673953965538504
# test set RMSE:28.905071258544922, R2:0.4245515370955525
# test set RMSE:110.64996337890625, R2:-11.367084787181593
# test set RMSE:15.554883003234863, R2:0.8560009464911922
# test set RMSE:16.790916442871094, R2:0.8028427616877774
# test set RMSE:26.685447692871094, R2:0.011868937220555043
# test set RMSE:95.73900604248047, R2:-1.1159128019464863
# test set RMSE:25.17096519470215, R2:-0.5519349054444567
# test set RMSE:31.99409294128418, R2:-0.4203820917555823
# test set RMSE:75.10116577148438, R2:-2.0487489400393604
# test set RMSE:37.605079650878906, R2:-13.692383521235199
# test set RMSE:27.146055221557617, R2:-0.8050417737361861
# test set RMSE:20.321250915527344, R2:-1.4483392940365434
# test set RMSE:57.7214469909668, R2:-1664.8828369140624
# test set RMSE:44.684757232666016, R2:-65.55758656284266
# test set RMSE:189.6381072998047, R2:-3.0607042050615254
# test set RMSE:28.802574157714844, R2:0.06155173800009217
# test set RMSE:23.680797576904297, R2:0.5478490054569771
# test set RMSE:36.327659606933594, R2:-0.4095580394224132
# test set RMSE:56.042293548583984, R2:-3.9800291454217573
# test set RMSE:78.64115142822266, R2:-2.04964750941603
# test set RMSE:28.655424118041992, R2:0.2801286490102135
# test set RMSE:129.5523223876953, R2:-2.2225418290666648
# test set RMSE:51.80523681640625, R2:0.406767720937937
# test set RMSE:144.36293029785156, R2:-1.1890871149317466
# test set RMSE:38.59944152832031, R2:0.3813280305453517
# test set RMSE:31.35659408569336, R2:-1.4787460418352039
# test set RMSE:23.521825790405273, R2:0.27950997994454685
# test set RMSE:18.84697723388672, R2:0.7271823693528405
# test set RMSE:44.77085876464844, R2:0.20551085937768332
# test set RMSE:42.51420974731445, R2:-66.15014144535282
# test set RMSE:28.723140716552734, R2:-0.1698247773548316
# test set RMSE:93.18293762207031, R2:-5.360051012065379
# test set RMSE:34.24186706542969, R2:-1.3130143194500161
# test set RMSE:41.382354736328125, R2:0.2971960137346784
# test set RMSE:75.11292266845703, R2:-37.402383513605564
# test set RMSE:57.69095993041992, R2:-0.31920590858473497
# test set RMSE:117.18639373779297, R2:-2.0096211763688334
# test set RMSE:30.773035049438477, R2:0.6679594299961223
# test set RMSE:127.26105499267578, R2:-6.88479833299069
# test set RMSE:16.708919525146484, R2:-0.9941999089946314
# test set RMSE:33.154239654541016, R2:0.5270208174511115
# test set RMSE:36.119102478027344, R2:-1.1169809904581962
# test set RMSE:68.86800384521484, R2:-1.598439685368224
# test set RMSE:28.062850952148438, R2:-0.277928694667644
# test set RMSE:24.732563018798828, R2:0.39330556289349405
# test set RMSE:36.77555465698242, R2:0.5642907483482471
# test set RMSE:71.85059356689453, R2:-17.421081214408893
# test set RMSE:73.6378173828125, R2:-13.941525198798404
# test set RMSE:160.75099182128906, R2:-3.5174392771831107
# test set RMSE:78.87496948242188, R2:-2.3181531438626597
# test set RMSE:66.4417724609375, R2:-1.323425805168113
# test set RMSE:15.482734680175781, R2:0.8573336730313822
# test set RMSE:34.88333511352539, R2:-0.29970304617109234
# test set RMSE:87.82704162597656, R2:-1.9546434061857125
# test set RMSE:94.03257751464844, R2:-0.9713788417684457
# test set RMSE:66.2262954711914, R2:0.21539854270084835
# test set RMSE:22.3958683013916, R2:-0.1296733447080347
# test set RMSE:45.91826629638672, R2:-12.691476225672947
# test set RMSE:58.937618255615234, R2:0.24518841886671483
# test set RMSE:31.08348846435547, R2:0.07564371703418848
# test set RMSE:52.39019775390625, R2:-27.516704142594538
# test set RMSE:11.326037406921387, R2:0.7653430840656726
# test set RMSE:75.09734344482422, R2:-51.258947549670204
# test set RMSE:46.33257293701172, R2:-0.19217359150011282
# test set RMSE:26.393268585205078, R2:0.6234569286057547
# test set RMSE:105.81002044677734, R2:-0.7636904150811208
# test set RMSE:17.452497482299805, R2:0.7583899895008349
# test set RMSE:28.647735595703125, R2:-98.47790453361742
# test set RMSE:22.693248748779297, R2:-5.8740859548295035
# test set RMSE:55.95622634887695, R2:-33.534185154552766
# test set RMSE:118.73331451416016, R2:-16.98163270699509
# test set RMSE:52.0324821472168, R2:-0.9830648039492873
# test set RMSE:48.874210357666016, R2:0.2904885638670208
# test set RMSE:252.84872436523438, R2:-5.597778356959934
# test set RMSE:49.96086502075195, R2:-3.4553110459797445
# test set RMSE:47.01399612426758, R2:-0.1788874754017049
# test set RMSE:114.0379867553711, R2:-0.4073295314419172
# test set RMSE:46.725502014160156, R2:-0.21248012287416596
# test set RMSE:45.614830017089844, R2:0.32266630828791887
# test set RMSE:29.94593620300293, R2:0.5086924621185569
# test set RMSE:87.33892059326172, R2:-1.9890623179605282
# test set RMSE:71.76771545410156, R2:-366.900390625
# test set RMSE:26.354581832885742, R2:-0.21004183985632907
# test set RMSE:94.65137481689453, R2:-2.720079947125052
# test set RMSE:26.653669357299805, R2:0.6451458310785949
# test set RMSE:24.92580223083496, R2:-5.455019393815987
# test set RMSE:54.1247673034668, R2:-7.322414970648039
# test set RMSE:73.93315124511719, R2:-0.03291713301801802

# %% [markdown]
# ---
#
# 여기까지 완성 코드

# %%
our_test_pre
# Out:
#        unit_nr  time_cycles  setting_1  setting_2  setting_3       s_2  \
# 0            1            1       20.0       0.70      100.0 -1.291986
# 1            1            2       25.0       0.62       60.0 -1.319291
# 2            1            3       42.0       0.84      100.0 -1.029485
# 3            1            4       42.0       0.84      100.0 -0.910432
# 4            1            5       35.0       0.84      100.0 -0.921847
# ...        ...          ...        ...        ...        ...       ...
# 41209      248          277       42.0       0.84      100.0  1.163527
# 41210      248          278       20.0       0.70      100.0  1.179629
# 41211      248          279       35.0       0.84      100.0  1.134908
# 41212      248          280       20.0       0.70      100.0  1.191251
# 41213      248          281       35.0       0.84      100.0  1.244271
#
#             s_3       s_4       s_7       s_8      s_11      s_12      s_13  \
# 0     -0.371035 -2.446822 -1.269701 -1.611846 -1.804439 -1.255108 -1.670254
# 1     -0.583102 -2.235578 -1.261752 -1.267885 -2.115486 -1.290563 -1.310588
# 2     -1.063450 -2.172079 -1.361982 -0.916181 -1.998272 -1.140364 -1.026640
# 3     -1.321252 -2.096013 -1.442700 -0.790000 -1.727776 -1.217803 -0.941823
# 4     -1.440679 -1.878822 -1.440650 -0.912838 -1.797539 -1.231150 -0.950081
# ...         ...       ...       ...       ...       ...       ...       ...
# 41209  0.983411  1.085424 -0.529470  0.991865  1.205009 -0.404955  0.983526
# 41210  1.054594  1.104077 -0.498381  1.004322  1.151275 -0.415745  0.978886
# 41211  1.041285  1.025245 -0.447348  1.110572  1.200215 -0.427757  1.063386
# 41212  1.021679  0.997851 -0.499888  1.091671  1.235251 -0.453318  1.069723
# 41213  1.134678  1.042113 -0.496913  1.161838  1.185344 -0.530531  1.126960
#
#            s_15      s_17      s_20      s_21  RUL          op_cond
# 0      0.498634 -1.682168 -1.285619 -0.196676  251   20.0_0.7_100.0
# 1      0.226689 -1.099450 -0.404059 -0.178507  250   25.0_0.62_60.0
# 2      0.470909 -1.258826 -0.979195  0.217581  249  42.0_0.84_100.0
# 3      0.444872 -1.338073 -0.848502 -0.400354  248  42.0_0.84_100.0
# 4      0.387552 -1.120656 -0.700182 -0.294075  247  35.0_0.84_100.0
# ...         ...       ...       ...       ...  ...              ...
# 41209  1.106291  0.984795 -0.587610 -0.855645   30  42.0_0.84_100.0
# 41210  1.129134  0.956208 -0.645923 -0.839880   29   20.0_0.7_100.0
# 41211  1.174226  1.000399 -0.724282 -0.868771   28  35.0_0.84_100.0
# 41212  1.183347  0.970252 -0.705739 -0.813108   27   20.0_0.7_100.0
# 41213  1.220428  0.951510 -0.755834 -0.830643   26  35.0_0.84_100.0
#
# [40954 rows x 19 columns]

# %%
threshold = 125
plt.figure(figsize=(48,150))
n=1
for id in (our_test_pre['unit_nr'].unique()):
  L = np.array([id])
  our_test = gen_data_wrapper(our_test_pre, sequence_length, sensors, L)
  our_y = gen_label_wrapper(our_test_pre, sequence_length, ['RUL'],L)
  index, y_actual, y_pred = everything(our_test, our_y,id)
  if (n%3==0):
    du = len(our_test_pre['unit_nr'].unique())
  else:
    du = len(our_test_pre['unit_nr'].unique())+1
  ax = plt.subplot(du,3,n)
  plt.xlabel('unit_'+str(id))
  ax.set_ylim(0,500)
  ax.plot(index,y_actual)
  ax.plot(index,y_pred)
  n+=1
plt.tight_layout()
plt.show()
# Out:
# test set RMSE:43.355953216552734, R2:0.4416617509765429
# test set RMSE:33.819583892822266, R2:0.10730594780265024
# test set RMSE:49.941444396972656, R2:-1.3861736071408335
# test set RMSE:65.46722412109375, R2:-0.6052273192716642
# test set RMSE:38.66910934448242, R2:-36.15030880825187
# test set RMSE:33.276371002197266, R2:0.02923697961543481
# test set RMSE:18.916757583618164, R2:-5.881609961298796
# test set RMSE:50.35602569580078, R2:0.3655389912339161
# test set RMSE:125.64867401123047, R2:-1.9135561465394768
# test set RMSE:55.1833381652832, R2:-12.013677770832704
# test set RMSE:52.450687408447266, R2:0.43159618781357956
# test set RMSE:70.7701416015625, R2:-0.5330703427344334
# test set RMSE:29.99749183654785, R2:-1.0266881777477255
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-250-8063a863b276> in <module>()
#       7   our_test = gen_data_wrapper(our_test_pre, sequence_length, sensors, L)
#       8   our_y = gen_label_wrapper(our_test_pre, sequence_length, ['RUL'],L)
# ----> 9   index, y_actual, y_pred = everything(our_test, our_y,id)
#      10   if (n%3==0):
#      11     du = len(our_test_pre['unit_nr'].unique())
#
# <ipython-input-249-15e4cbe57c33> in everything(our_test, our_y, id)
#      24   test_mu = viz_latent_space(RVE.encoder, our_test, our_y.clip(max=threshold))
#      25         # Evaluate
# ---> 26   y_hat_test = RVE.regressor.predict(test_mu)
#      27
#      28   evaluate(our_y, y_hat_test, 'test')
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1976       callbacks.on_predict_begin()
#    1977       batch_outputs = None
# -> 1978       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1979         with data_handler.catch_stop_iteration():
#    1980           for step in data_handler.steps():
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1189     """Yields `(epoch, tf.data.Iterator)`."""
#    1190     with self._truncate_execution_to_epoch():
# -> 1191       data_iterator = iter(self._dataset)
#    1192       for epoch in range(self._initial_epoch, self._epochs):
#    1193         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     753             "When `dataset` is provided, `element_spec` and `components` must "
#     754             "not be specified.")
# --> 755       self._create_iterator(dataset)
#     756
#     757     self._get_next_call_count = 0
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     785                 output_types=self._flat_output_types,
#     786                 output_shapes=self._flat_output_shapes))
# --> 787         gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     788         # Delete the resource when this object is deleted
#     789         self._resource_deleter = IteratorResourceDeleter(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3314     try:
#    3315       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 3316         _ctx, "MakeIterator", name, dataset, iterator)
#    3317       return _result
#    3318     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
for id in (our_test_pre['unit_nr'].unique()):
  L = np.array([id])
  our_test = gen_data_wrapper(our_test_pre, sequence_length, sensors, L)
  our_y = gen_label_wrapper(our_test_pre, sequence_length, ['RUL'],L)

# %%
our_test_pre.info() #40954

# %%
our_test_pre.iloc[-261:,:]

# %%
our_y

# %%
our_train = train.copy()
a = temp_x.groupby(by="unit_nr")["time_cycles"].max()
index = a.index
b = temp_y['RemainingUsefulLife'].tolist()
bb = pd.Series(b, index)
c = a+ bb
result_frame = temp_x.merge(c.to_frame(name='max_cycle'), left_on='unit_nr', right_index=True)
rruull = result_frame["max_cycle"] - result_frame["time_cycles"]
result_frame["RUL"] = rruull
result_frame = result_frame.drop("max_cycle", axis=1)

drop_sensors = [element for element in sensor_names if element not in sensors]
print(drop_sensors)
our_train_pre = add_operating_condition(our_train.drop(drop_sensors, axis=1))
our_test_pre = add_operating_condition(result_frame.drop(drop_sensors, axis=1))
our_train_pre, our_test_pre = condition_scaler(our_train_pre, our_test_pre, sensors)
# Out:
# ['s_1', 's_5', 's_6', 's_9', 's_10', 's_14', 's_16', 's_18', 's_19']

# %%
pd.options.display.max_rows = 60
pd.options.display.max_columns = 20

our_test_pre_248 = our_test_pre[our_test_pre['unit_nr']==248]
our_test_pre_248
# Out:
#        unit_nr  time_cycles  setting_1  setting_2  setting_3       s_2  \
# 40933      248            1       42.0       0.84      100.0 -1.373838
# 40934      248            2       42.0       0.84      100.0 -0.404697
# 40935      248            3        0.0       0.00      100.0 -0.557436
# 40936      248            4       25.0       0.62       60.0 -0.592364
# 40937      248            5       25.0       0.62       60.0  0.444191
# ...        ...          ...        ...        ...        ...       ...
# 41209      248          277       42.0       0.84      100.0  1.770487
# 41210      248          278       20.0       0.70      100.0  1.324548
# 41211      248          279       35.0       0.84      100.0  0.732416
# 41212      248          280       20.0       0.70      100.0  1.698339
# 41213      248          281       35.0       0.84      100.0  1.721447
#
#             s_3       s_4       s_7       s_8      s_11      s_12      s_13  \
# 40933 -0.115630 -0.473544 -0.278337 -0.775327 -0.372987 -0.255738 -0.541090
# 40934  0.158772 -0.227401 -0.056292 -0.859065 -0.025463  0.152322 -0.773727
# 40935 -0.652941 -0.431536 -0.266471 -0.432621 -1.217954 -0.342086 -0.228896
# 40936 -1.067888  0.303300 -0.139222 -0.910839 -0.446691  0.096559 -0.628634
# 40937  0.059685 -1.184068 -0.100761 -0.673433 -0.280841  0.326108 -0.628634
# ...         ...       ...       ...       ...       ...       ...       ...
# 41209  1.794574  0.518790 -0.567961  1.443733  0.912852  0.047691  1.591417
# 41210  1.695244  1.271952 -0.218582  1.116441  0.667678 -0.512856  0.937124
# 41211  0.921504  0.315760  0.011947  2.066816  1.640667 -0.535863  1.823885
# 41212  0.845221  0.751301 -0.972748  0.921564  1.550577 -0.683373  1.126752
# 41213  2.151677  1.440476 -0.470136  1.793340  0.736179 -1.225445  1.642098
#
#            s_15      s_17      s_20      s_21  RUL          op_cond
# 40933  0.705616 -0.929365  2.757572  1.091254  306  42.0_0.84_100.0
# 40934  0.005854  0.274621 -0.361164  0.088397  305  42.0_0.84_100.0
# 40935 -0.324572 -0.390342 -0.262617 -0.133204  304    0.0_0.0_100.0
# 40936 -0.064731 -0.575005 -0.312998 -1.289791  303   25.0_0.62_60.0
# 40937  0.260583 -0.575005 -1.405532  0.520707  302   25.0_0.62_60.0
# ...         ...       ...       ...       ...  ...              ...
# 41209  1.535632  0.274621 -0.782615 -1.552641   30  42.0_0.84_100.0
# 41210  1.334723  0.698928 -1.170732 -0.697992   29   20.0_0.7_100.0
# 41211  1.580054  1.398115 -1.429515 -1.128793   28  35.0_0.84_100.0
# 41212  1.265434  0.698928 -0.538850 -0.312142   27   20.0_0.7_100.0
# 41213  1.554152  0.782835 -1.206690 -0.988459   26  35.0_0.84_100.0
#
# [281 rows x 19 columns]

# %%
temp = our_test_pre_248.copy()
sensors =  ['s_2', 's_3', 's_4', 's_7', 's_8', 's_11', 's_12', 's_13', 's_15', 's_17', 's_20', 's_21']
k = temp.groupby('unit_nr')[sensors].apply(lambda x: x.ewm(alpha=0.1).mean())

# %%
k
# Out:
#             s_2       s_3       s_4       s_7       s_8      s_11      s_12  \
# 40933 -1.373838 -0.115630 -0.473544 -0.278337 -0.775327 -0.372987 -0.255738
# 40934 -0.863764  0.028792 -0.343995 -0.161471 -0.819400 -0.190080 -0.040970
# 40935 -0.750728 -0.222770 -0.376298 -0.200217 -0.676677 -0.569369 -0.152083
# 40936 -0.704678 -0.468515 -0.178683 -0.182481 -0.744767 -0.533697 -0.079782
# 40937 -0.424131 -0.339532 -0.424192 -0.162525 -0.727348 -0.471951  0.019334
# ...         ...       ...       ...       ...       ...       ...       ...
# 41209  1.163527  0.983411  1.085424 -0.529470  0.991865  1.205009 -0.404955
# 41210  1.179629  1.054594  1.104077 -0.498381  1.004322  1.151275 -0.415745
# 41211  1.134908  1.041285  1.025245 -0.447348  1.110572  1.200215 -0.427757
# 41212  1.191251  1.021679  0.997851 -0.499888  1.091671  1.235251 -0.453318
# 41213  1.244271  1.134678  1.042113 -0.496913  1.161838  1.185344 -0.530531
#
#            s_13      s_15      s_17      s_20      s_21
# 40933 -0.541090  0.705616 -0.929365  2.757572  1.091254
# 40934 -0.663530  0.337320 -0.295688  1.116132  0.563435
# 40935 -0.503149  0.093079 -0.330616  0.607369  0.306372
# 40936 -0.539638  0.047191 -0.401680  0.339742 -0.157764
# 40937 -0.561370  0.099300 -0.444005 -0.086444  0.007915
# ...         ...       ...       ...       ...       ...
# 41209  0.983526  1.106291  0.984795 -0.587610 -0.855645
# 41210  0.978886  1.129134  0.956208 -0.645923 -0.839880
# 41211  1.063386  1.174226  1.000399 -0.724282 -0.868771
# 41212  1.069723  1.183347  0.970252 -0.705739 -0.813108
# 41213  1.126960  1.220428  0.951510 -0.755834 -0.830643
#
# [281 rows x 12 columns]

# %%
temp[sensors] = k

# %%
temp
# Out:
#        unit_nr  time_cycles  setting_1  setting_2  setting_3       s_2  \
# 40933      248            1       42.0       0.84      100.0 -1.373838
# 40934      248            2       42.0       0.84      100.0 -0.863764
# 40935      248            3        0.0       0.00      100.0 -0.750728
# 40936      248            4       25.0       0.62       60.0 -0.704678
# 40937      248            5       25.0       0.62       60.0 -0.424131
# ...        ...          ...        ...        ...        ...       ...
# 41209      248          277       42.0       0.84      100.0  1.163527
# 41210      248          278       20.0       0.70      100.0  1.179629
# 41211      248          279       35.0       0.84      100.0  1.134908
# 41212      248          280       20.0       0.70      100.0  1.191251
# 41213      248          281       35.0       0.84      100.0  1.244271
#
#             s_3       s_4       s_7       s_8      s_11      s_12      s_13  \
# 40933 -0.115630 -0.473544 -0.278337 -0.775327 -0.372987 -0.255738 -0.541090
# 40934  0.028792 -0.343995 -0.161471 -0.819400 -0.190080 -0.040970 -0.663530
# 40935 -0.222770 -0.376298 -0.200217 -0.676677 -0.569369 -0.152083 -0.503149
# 40936 -0.468515 -0.178683 -0.182481 -0.744767 -0.533697 -0.079782 -0.539638
# 40937 -0.339532 -0.424192 -0.162525 -0.727348 -0.471951  0.019334 -0.561370
# ...         ...       ...       ...       ...       ...       ...       ...
# 41209  0.983411  1.085424 -0.529470  0.991865  1.205009 -0.404955  0.983526
# 41210  1.054594  1.104077 -0.498381  1.004322  1.151275 -0.415745  0.978886
# 41211  1.041285  1.025245 -0.447348  1.110572  1.200215 -0.427757  1.063386
# 41212  1.021679  0.997851 -0.499888  1.091671  1.235251 -0.453318  1.069723
# 41213  1.134678  1.042113 -0.496913  1.161838  1.185344 -0.530531  1.126960
#
#            s_15      s_17      s_20      s_21  RUL          op_cond
# 40933  0.705616 -0.929365  2.757572  1.091254  306  42.0_0.84_100.0
# 40934  0.337320 -0.295688  1.116132  0.563435  305  42.0_0.84_100.0
# 40935  0.093079 -0.330616  0.607369  0.306372  304    0.0_0.0_100.0
# 40936  0.047191 -0.401680  0.339742 -0.157764  303   25.0_0.62_60.0
# 40937  0.099300 -0.444005 -0.086444  0.007915  302   25.0_0.62_60.0
# ...         ...       ...       ...       ...  ...              ...
# 41209  1.106291  0.984795 -0.587610 -0.855645   30  42.0_0.84_100.0
# 41210  1.129134  0.956208 -0.645923 -0.839880   29   20.0_0.7_100.0
# 41211  1.174226  1.000399 -0.724282 -0.868771   28  35.0_0.84_100.0
# 41212  1.183347  0.970252 -0.705739 -0.813108   27   20.0_0.7_100.0
# 41213  1.220428  0.951510 -0.755834 -0.830643   26  35.0_0.84_100.0
#
# [281 rows x 19 columns]

# %%
sensors =  ['s_2', 's_3', 's_4', 's_7', 's_8', 's_11', 's_12', 's_13', 's_15', 's_17', 's_20', 's_21']
temp[sensors] = temp.groupby('unit_nr')[sensors].apply(lambda x: x.ewm(alpha=alpha).mean())
temp[sensors]
# Out:
#        s_2  s_3  s_4  s_7  s_8  s_11  s_12  s_13  s_15  s_17  s_20  s_21
# 40933  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 40934  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 40935  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 40936  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 40937  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...  ...  ...  ...  ...   ...   ...   ...   ...   ...   ...   ...
# 41209  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 41210  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 41211  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 41212  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 41213  NaN  NaN  NaN  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [281 rows x 12 columns]

# %%
temp
# Out:
#        unit_nr  time_cycles  setting_1  setting_2  setting_3  s_2  s_3  s_4  \
# 40933      248            1       42.0       0.84      100.0  NaN  NaN  NaN
# 40934      248            2       42.0       0.84      100.0  NaN  NaN  NaN
# 40935      248            3        0.0       0.00      100.0  NaN  NaN  NaN
# 40936      248            4       25.0       0.62       60.0  NaN  NaN  NaN
# 40937      248            5       25.0       0.62       60.0  NaN  NaN  NaN
# ...        ...          ...        ...        ...        ...  ...  ...  ...
# 41209      248          277       42.0       0.84      100.0  NaN  NaN  NaN
# 41210      248          278       20.0       0.70      100.0  NaN  NaN  NaN
# 41211      248          279       35.0       0.84      100.0  NaN  NaN  NaN
# 41212      248          280       20.0       0.70      100.0  NaN  NaN  NaN
# 41213      248          281       35.0       0.84      100.0  NaN  NaN  NaN
#
#        s_7  s_8  s_11  s_12  s_13  s_15  s_17  s_20  s_21  RUL  \
# 40933  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  306
# 40934  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  305
# 40935  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  304
# 40936  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  303
# 40937  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  302
# ...    ...  ...   ...   ...   ...   ...   ...   ...   ...  ...
# 41209  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   30
# 41210  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   29
# 41211  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   28
# 41212  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   27
# 41213  NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   26
#
#                op_cond
# 40933  42.0_0.84_100.0
# 40934  42.0_0.84_100.0
# 40935    0.0_0.0_100.0
# 40936   25.0_0.62_60.0
# 40937   25.0_0.62_60.0
# ...                ...
# 41209  42.0_0.84_100.0
# 41210   20.0_0.7_100.0
# 41211  35.0_0.84_100.0
# 41212   20.0_0.7_100.0
# 41213  35.0_0.84_100.0
#
# [281 rows x 19 columns]

# %%
def exponential_smoothing(df, sensors, n_samples, alpha=0.4):
    df = df.copy()
    # first, take the exponential weighted mean
    df[sensors] = df.groupby('unit_nr')[sensors].apply(lambda x: x.ewm(alpha=alpha).mean()).reset_index(level=0, drop=True)
    
    # second, drop first n_samples of each unit_nr to reduce filter delay
    def create_mask(data, samples):
        result = np.ones_like(data)
        result[0:samples] = 0
        return result
    
    mask = df.groupby('unit_nr')['unit_nr'].transform(create_mask, samples=n_samples).astype(bool)
    df = df[mask]
    
    return df

# %%
our_test_pre

# %%
our_test_pre = exponential_smoothing(our_test_pre, sensors, 0, alpha)
#sensors =  ['s_2', 's_3', 's_4', 's_7', 's_8', 's_11', 's_12', 's_13', 's_15', 's_17', 's_20', 's_21']

# %%
our_test_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40954 entries, 0 to 41213
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   unit_nr      40954 non-null  int64
#  1   time_cycles  40954 non-null  int64
#  2   setting_1    40954 non-null  float64
#  3   setting_2    40954 non-null  float64
#  4   setting_3    40954 non-null  float64
#  5   s_2          40694 non-null  float64
#  6   s_3          40694 non-null  float64
#  7   s_4          40694 non-null  float64
#  8   s_7          40694 non-null  float64
#  9   s_8          40694 non-null  float64
#  10  s_11         40694 non-null  float64
#  11  s_12         40694 non-null  float64
#  12  s_13         40694 non-null  float64
#  13  s_15         40694 non-null  float64
#  14  s_17         40694 non-null  float64
#  15  s_20         40694 non-null  float64
#  16  s_21         40694 non-null  float64
#  17  RUL          40954 non-null  int64
#  18  op_cond      40954 non-null  object
# dtypes: float64(15), int64(3), object(1)
# memory usage: 6.2+ MB

# %%
pd.set_option('display.max_rows',None)
our_test_pre[our_test_pre['s_21'].isnull()]

# %%
41213-40954
# Out:
# 259
